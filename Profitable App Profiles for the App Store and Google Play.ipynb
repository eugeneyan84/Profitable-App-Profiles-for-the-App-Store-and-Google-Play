# %% [markdown]
# ## Profitable App Profiles for the App Store and Google Play Markets
#
# In-app advertisements has always been the main source of revenue for every company developing mobile apps. Revenue generated from any given app is very much influenced by the size of the user-base - the more users see and engage with the ads, the better.
#
# As such, the goal of this project is to analyze data to help identify the types of apps that would likely attract a huge user-base. We will carry out our analysis based on the [Google Play data set](https://www.kaggle.com/lava18/google-play-store-apps), as well as the [iOS App Store data set](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps) made available at the respective Kaggle webpages.

# %%
from csv import reader
import statistics

def open_dataset(path, has_header=True):
    openedFile = open(path)
    csvHandle = reader(openedFile)
    data = list(csvHandle)
    if has_header:
        return data[1:], data[0]
    else:
        return data
    
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]    
    for row in dataset_slice:
        print(row)
        print('\n') # adds a new (empty) line after each row
    if rows_and_columns:
        print('Row-count:', len(dataset))
        print('Column-count:', len(dataset[0]))

def clean_malformed_rows(dataset_without_header, header, data_set_name = ''):
    print('Cleaning '+ data_set_name +', original row-count:' + str(len(dataset_without_header)))
    headerlength = len(header)
    result = []
    for record in dataset_without_header:
        rowlength = len(record)
        if rowlength != headerlength:
            print(record)
            errorMsg = 'Index ' + str(dataset_without_header.index(record)) + ': Expected ' + str(headerlength) + ' elements, found ' + str(rowlength) + '.'
            print(errorMsg)
        else:
            result.append(record)
    print('Cleaning completed, final row-count: '+str(len(result))+'\n')
    return result

# %%
apple_apps_data, apple_data_headers = open_dataset('AppleStore.csv')
google_apps_data, google_data_headers = open_dataset('googleplaystore.csv')

#print(apple_data_headers)
#explore_data(apple_apps_data, 0, 3, True)
print('Cleaning malformed rows in Apple data set:')
apple_cleaned_rows_apps_data = clean_malformed_rows(apple_apps_data, apple_data_headers)

#print(google_data_headers)
#explore_data(google_apps_data, 0, 3, True)
print('Cleaning malformed rows in Google data set:')
google_cleaned_rows_apps_data = clean_malformed_rows(google_apps_data, google_data_headers)
# Out:
# Cleaning malformed rows in Apple data set:
# Cleaning , original row-count:7197
# Cleaning completed, final row-count: 7197
#
# Cleaning malformed rows in Google data set:
# Cleaning , original row-count:10841
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']
# Index 10472: Expected 13 elements, found 12.
# Cleaning completed, final row-count: 10840

# %% [markdown]
# The clean_malformed_rows method calls have cleaned up both data sets by removing malformed rows.
#
# Exploration revealed that Google Play data set has incidences of repeated app names. Before we proceed further, it would be good to take note of the various columns made available in both data sets.
#
# Column descriptions for the Google Play data set as follows:
#
# | Syntax      | Description |
# | ----------- | ----------- |
# |App | Application name |
# |Category | Category the app belongs to |
# |Rating | Overall user rating of the app (as when scraped) |
# |Reviews | Number of user reviews for the app (as when scraped) |
# |Size | Size of the app (as when scraped) |
# |Installs | Number of user downloads/installs for the app (as when scraped) |
# |Type | Paid or Free |
# |Price | Price of the app (as when scraped) |
# |Content Rating | Age group the app is targeted at - Children / Mature 21+ / Adult |
# |Genres | An app can belong to multiple genres (apart from its main category). For eg, a musical family game will belong to Music, Game, Family genres. |
# |Last Updated | Date when the app was last updated on Play Store (as when scraped) |
# |Current Ver | Current version of the app available on Play Store (as when scraped) |
# |Android Ver | Min required Android version (as when scraped) |
#
# Column descriptions for the App Store data set as follows:
#
# | Syntax      | Description |
# | ----------- | ----------- |
# | id | App ID |
# | track_name | App Name |
# | size_bytes | Size in bytes |
# | currency | Currency Type |
# | price | Price amount |
# | rating_count_tot | User Rating counts (for all versions) |
# | rating_count_ver | User rating counts (for current version) |
# | user_rating | Average User Rating value (for all versions) |
# | user_rating_ver | Average User Rating value (for current version) |
# | ver | Latest version code |
# | cont_rating | Content Rating |
# | prime_genre | Primary Genre |
# | sup_devices.num | Number of supporting devices |
# | ipadSc_urls.num | Number of screenshots showed for display |
# | lang.num | Number of supported languages |
# | vpp_lic | Vpp Device Licensing Enabled |
#
# A preliminary inspection function is then built to look closer at the app with greatest duplicate count in both data sets.

# %%
def build_app_dict(dataset_without_header, app_name_index):
    app_dict = {}
    for app in dataset_without_header:
        if app[app_name_index] not in app_dict.keys():
            app_dict[app[app_name_index]] = [app]
        else:
            app_dict[app[app_name_index]].append(app)
    return app_dict

apple_app_dict = build_app_dict(apple_cleaned_rows_apps_data, 1)

google_app_dict = build_app_dict(google_cleaned_rows_apps_data, 0)

def inspect_most_duplicated_app(app_dict):
    target = 0
    app_count_list = []
    for k,v in app_dict.items():
        app_count_list.append([k, len(v)])
        if len(v) > target:
            target = len(v)
    print('Highest duplicate count: '+str(target))
    app_target = [i[0] for i in app_count_list if i[1] == target][0]
    for item in app_dict[app_target]:
        print(item)

print('Inspecting Apple app with highest duplicate count:')
inspect_most_duplicated_app(apple_app_dict)
print('\n')
print('Inspecting Google app with highest duplicate count:')
inspect_most_duplicated_app(google_app_dict)
# Out:
# Inspecting Apple app with highest duplicate count:
# Highest duplicate count: 2
# ['952877179', 'VR Roller Coaster', '169523200', 'USD', '0.0', '107', '102', '3.5', '3.5', '2.0.0', '4+', 'Games', '37', '5', '1', '1']
# ['1089824278', 'VR Roller Coaster', '240964608', 'USD', '0.0', '67', '44', '3.5', '4.0', '0.81', '4+', 'Games', '38', '0', '1', '1']
#
#
# Inspecting Google app with highest duplicate count:
# Highest duplicate count: 9
# ['ROBLOX', 'GAME', '4.5', '4447388', '67M', '100,000,000+', 'Free', '0', 'Everyone 10+', 'Adventure;Action & Adventure', 'July 31, 2018', '2.347.225742', '4.1 and up']
# ['ROBLOX', 'GAME', '4.5', '4447346', '67M', '100,000,000+', 'Free', '0', 'Everyone 10+', 'Adventure;Action & Adventure', 'July 31, 2018', '2.347.225742', '4.1 and up']
# ['ROBLOX', 'GAME', '4.5', '4448791', '67M', '100,000,000+', 'Free', '0', 'Everyone 10+', 'Adventure;Action & Adventure', 'July 31, 2018', '2.347.225742', '4.1 and up']
# ['ROBLOX', 'GAME', '4.5', '4449882', '67M', '100,000,000+', 'Free', '0', 'Everyone 10+', 'Adventure;Action & Adventure', 'July 31, 2018', '2.347.225742', '4.1 and up']
# ['ROBLOX', 'GAME', '4.5', '4449910', '67M', '100,000,000+', 'Free', '0', 'Everyone 10+', 'Adventure;Action & Adventure', 'July 31, 2018', '2.347.225742', '4.1 and up']
# ['ROBLOX', 'FAMILY', '4.5', '4449910', '67M', '100,000,000+', 'Free', '0', 'Everyone 10+', 'Adventure;Action & Adventure', 'July 31, 2018', '2.347.225742', '4.1 and up']
# ['ROBLOX', 'FAMILY', '4.5', '4450855', '67M', '100,000,000+', 'Free', '0', 'Everyone 10+', 'Adventure;Action & Adventure', 'July 31, 2018', '2.347.225742', '4.1 and up']
# ['ROBLOX', 'FAMILY', '4.5', '4450890', '67M', '100,000,000+', 'Free', '0', 'Everyone 10+', 'Adventure;Action & Adventure', 'July 31, 2018', '2.347.225742', '4.1 and up']
# ['ROBLOX', 'FAMILY', '4.5', '4443407', '67M', '100,000,000+', 'Free', '0', 'Everyone 10+', 'Adventure;Action & Adventure', 'July 31, 2018', '2.347.225742', '4.1 and up']

# %% [markdown]
# With the help of the column descriptions, it can be observed that rating/review-related metrics differ across the duplicated records for a given app ('rating_count_tot' in App Store data set, and 'Reviews' in Google Play data set). Assuming that ratings and reviews cannot be deleted once published, it can be said that the record holding the highest count of the associated metric would be the most recent one, which ought to be considered for the next stage of data analysis.
#
# We then create another function to inspect all apps with duplicate records, and only take the record with the highest count of the respective metric, while disposing off the other duplicates.

# %%
def clean_duplicates(app_dict, target_index):
    result = []
    for k,record_list in app_dict.items():
        if len(record_list) == 1:
            result.append(record_list[0]) # immediately take the only element in the list
        else:
            print('Processing ' + str(len(record_list)) + ' records found for '+k)
            target_count = 0
            for item in record_list:
                if int(item[target_index]) > target_count:
                    target_count = int(item[target_index])
            print('Targeted metric value: '+str(target_count))
            target_record_list = [record for record in record_list if int(record[target_index]) == target_count] # filter first
            target_record = target_record_list[0] #take 1st record after filtering
            result.append(target_record)
    print('\n')
    return result

apple_unique_cleaned_rows_apps_data = clean_duplicates(apple_app_dict, 5) # rating_count_tot at index 5

google_unique_cleaned_rows_apps_data = clean_duplicates(google_app_dict, 3) # Reviews at index 3

print('\nApp store original record count:' + str(len(apple_apps_data)) + ', after duplicate removal: '+str(len(apple_unique_cleaned_rows_apps_data))+'\n')
print('Google Play original record count:' + str(len(google_apps_data)) + ', after duplicate removal: '+str(len(google_unique_cleaned_rows_apps_data))+'\n')
# Out:
# Processing 2 records found for VR Roller Coaster
# Targeted metric value: 107
# Processing 2 records found for Mannequin Challenge
# Targeted metric value: 668
#
#
# Processing 4 records found for Angry Birds Rio
# Targeted metric value: 2610680
# Processing 4 records found for Cymera Camera- Photo Editor, Filter,Collage,Layout
# Targeted metric value: 2418165
# Processing 3 records found for Booking.com Travel Deals
# Targeted metric value: 1830388
# Processing 2 records found for Anthem Anywhere
# Targeted metric value: 2657
# Processing 2 records found for PBS KIDS Video
# Targeted metric value: 36214
# Processing 5 records found for Viber Messenger
# Targeted metric value: 11335481
# Processing 2 records found for Phogy, 3D Camera
# Targeted metric value: 35725
# Processing 3 records found for mySugr: the blood sugar tracker made just for you
# Targeted metric value: 21189
# Processing 7 records found for 8 Ball Pool
# Targeted metric value: 14201891
# Processing 2 records found for Endomondo - Running & Walking
# Targeted metric value: 559262
# Processing 3 records found for Run with Map My Run
# Targeted metric value: 183669
# Processing 4 records found for Hulu: Stream TV, Movies & more
# Targeted metric value: 319777
# Processing 2 records found for Camera MX - Free Photo & Video Camera
# Targeted metric value: 244371
# Processing 2 records found for Chictopia
# Targeted metric value: 360
# Processing 2 records found for LINE WEBTOON - Free Comics
# Targeted metric value: 1013944
# Processing 2 records found for SHAREit - Transfer & Share
# Targeted metric value: 7790693
# Processing 2 records found for YouTube Studio
# Targeted metric value: 436921
# Processing 2 records found for Millionaire Match: Rich Singles Dating App
# Targeted metric value: 853
# Processing 3 records found for Checkout 51: Grocery coupons
# Targeted metric value: 52896
# Processing 2 records found for Edmodo
# Targeted metric value: 200214
# Processing 2 records found for ZALORA Fashion Shopping
# Targeted metric value: 142512
# Processing 2 records found for Hungry Shark World
# Targeted metric value: 1243017
# Processing 2 records found for Genius Scan - PDF Scanner
# Targeted metric value: 42492
# Processing 2 records found for Glide - Video Chat Messenger
# Targeted metric value: 350154
# Processing 2 records found for Transit: Real-Time Transit App
# Targeted metric value: 43269
# Processing 2 records found for Apartments & Rentals - Zillow
# Targeted metric value: 27387
# Processing 2 records found for stranger chat - anonymous chat
# Targeted metric value: 13204
# Processing 2 records found for Cricbuzz - Live Cricket Scores & News
# Targeted metric value: 838765
# Processing 2 records found for Swamp Attack
# Targeted metric value: 2119235
# Processing 3 records found for Credit Karma
# Targeted metric value: 706618
# Processing 2 records found for Free phone calls, free texting SMS on free number
# Targeted metric value: 412888
# Processing 2 records found for Mcqueen Coloring pages
# Targeted metric value: 65
# Processing 2 records found for H&M
# Targeted metric value: 41941
# Processing 2 records found for BP Journal - Blood Pressure Diary
# Targeted metric value: 6
# Processing 2 records found for The 5th Stand
# Targeted metric value: 1697
# Processing 2 records found for Dating for 50 plus Mature Singles – FINALLY
# Targeted metric value: 13049
# Processing 3 records found for Opera Browser: Fast and Secure
# Targeted metric value: 2473795
# Processing 2 records found for Bita and the Animals - Pelos Ares
# Targeted metric value: 1160
# Processing 2 records found for Hopper - Watch & Book Flights
# Targeted metric value: 52029
# Processing 2 records found for Love Balls
# Targeted metric value: 360630
# Processing 2 records found for Fitbit Coach
# Targeted metric value: 28951
# Processing 3 records found for Puffin Web Browser
# Targeted metric value: 541661
# Processing 3 records found for Messenger – Text and Video Chat for Free
# Targeted metric value: 56646578
# Processing 2 records found for Vargo Anesthesia Mega App
# Targeted metric value: 92
# Processing 3 records found for Maps - Navigate & Explore
# Targeted metric value: 9235373
# Processing 2 records found for Masha and the Bear Child Games
# Targeted metric value: 288606
# Processing 4 records found for The Coupons App
# Targeted metric value: 181990
# Processing 4 records found for ESPN Fantasy Sports
# Targeted metric value: 176487
# Processing 2 records found for Hotels.com: Book Hotel Rooms & Find Vacation Deals
# Targeted metric value: 260133
# Processing 2 records found for Dairy Queen
# Targeted metric value: 742
# Processing 2 records found for Sonic Dash
# Targeted metric value: 3778921
# Processing 2 records found for Advanced Comprehension Therapy
# Targeted metric value: 3
# Processing 3 records found for LivingSocial - Local Deals
# Targeted metric value: 28523
# Processing 2 records found for MailChimp - Email, Marketing Automation
# Targeted metric value: 5448
# Processing 2 records found for Rider
# Targeted metric value: 655145
# Processing 2 records found for imo beta free calls and text
# Targeted metric value: 659395
# Processing 5 records found for MeetMe: Chat & Meet New People
# Targeted metric value: 1259894
# Processing 2 records found for YouTube Gaming
# Targeted metric value: 130549
# Processing 3 records found for Google Classroom
# Targeted metric value: 69498
# Processing 2 records found for Toy Blast
# Targeted metric value: 1889582
# Processing 2 records found for Medical ID - In Case of Emergency (ICE)
# Targeted metric value: 717
# Processing 3 records found for Equestria Girls
# Targeted metric value: 392819
# Processing 2 records found for All Football - Latest News & Videos
# Targeted metric value: 152867
# Processing 4 records found for imo free video calls and chat
# Targeted metric value: 4785988
# Processing 2 records found for Ibotta: Cash Back Savings, Rewards & Coupons App
# Targeted metric value: 315908
# Processing 2 records found for Random Video Chat
# Targeted metric value: 3
# Processing 2 records found for BBM - Free Calls & Messages
# Targeted metric value: 12843436
# Processing 3 records found for Todoist: To-do lists for task management & errands
# Targeted metric value: 155999
# Processing 2 records found for IBM Micromedex Drug Info
# Targeted metric value: 206
# Processing 2 records found for Vaniday - Beauty Booking App
# Targeted metric value: 1067
# Processing 2 records found for MLB Ballpark
# Targeted metric value: 5511
# Processing 4 records found for Talking Tom Gold Run
# Targeted metric value: 2698889
# Processing 2 records found for Google Earth
# Targeted metric value: 2339098
# Processing 3 records found for Wunderlist: To-Do List & Tasks
# Targeted metric value: 404617
# Processing 2 records found for My Little Pony: Harmony Quest
# Targeted metric value: 148405
# Processing 2 records found for 8fit Workouts & Meal Planner
# Targeted metric value: 115721
# Processing 2 records found for Breastfeeding Tracker Baby Log
# Targeted metric value: 6
# Processing 2 records found for Fuzzy Numbers: Pre-K Number Foundation
# Targeted metric value: 21
# Processing 2 records found for Beautiful Widgets Pro
# Targeted metric value: 97890
# Processing 3 records found for Lifetime - Watch Full Episodes & Original Movies
# Targeted metric value: 35931
# Processing 2 records found for Postmates Food Delivery: Order Eats & Alcohol
# Targeted metric value: 22875
# Processing 2 records found for Vigo Video
# Targeted metric value: 1615596
# Processing 4 records found for Zombie Hunter King
# Targeted metric value: 10538
# Processing 2 records found for Candy Bomb
# Targeted metric value: 42145
# Processing 2 records found for Hangouts Dialer - Call Phones
# Targeted metric value: 122512
# Processing 2 records found for Teladoc Member
# Targeted metric value: 2094
# Processing 2 records found for Learn 50 languages
# Targeted metric value: 55256
# Processing 3 records found for Firefox Focus: The privacy browser
# Targeted metric value: 36981
# Processing 2 records found for Alto's Adventure
# Targeted metric value: 515657
# Processing 2 records found for Merge Dragons!
# Targeted metric value: 214819
# Processing 3 records found for CNN Breaking US & World News
# Targeted metric value: 293080
# Processing 3 records found for UC Browser Mini -Tiny Fast Private & Secure
# Targeted metric value: 3648765
# Processing 3 records found for Priceline Hotel Deals, Rental Cars & Flights
# Targeted metric value: 48930
# Processing 2 records found for iBP Blood Pressure
# Targeted metric value: 578
# Processing 3 records found for Moco - Chat, Meet People
# Targeted metric value: 313769
# Processing 2 records found for Backgrounds HD (Wallpapers)
# Targeted metric value: 2390185
# Processing 2 records found for Facebook Pages Manager
# Targeted metric value: 1279800
# Processing 2 records found for Period Tracker
# Targeted metric value: 325738
# Processing 2 records found for osmino Wi-Fi: free WiFi
# Targeted metric value: 134203
# Processing 2 records found for Diary with lock
# Targeted metric value: 815893
# Processing 2 records found for edX - Online Courses by Harvard, MIT & more
# Targeted metric value: 32381
# Processing 2 records found for Talking Ben the Dog
# Targeted metric value: 1633682
# Processing 2 records found for Tapatalk - 100,000+ Forums
# Targeted metric value: 285820
# Processing 3 records found for Twitter
# Targeted metric value: 11667403
# Processing 4 records found for Pou
# Targeted metric value: 10486018
# Processing 4 records found for Evernote – Organizer, Planner for Notes & Memos
# Targeted metric value: 1488397
# Processing 2 records found for HipChat - Chat Built for Teams
# Targeted metric value: 5868
# Processing 2 records found for Blood Pressure Log - MyDiary
# Targeted metric value: 8348
# Processing 2 records found for Walk with Map My Walk
# Targeted metric value: 144050
# Processing 5 records found for Skyscanner
# Targeted metric value: 481546
# Processing 2 records found for Real Racing 3
# Targeted metric value: 354454
# Processing 2 records found for CJmall
# Targeted metric value: 18253
# Processing 2 records found for Google+
# Targeted metric value: 4831125
# Processing 2 records found for Candy Crush Jelly Saga
# Targeted metric value: 1300619
# Processing 2 records found for Telemundo Now
# Targeted metric value: 8674
# Processing 2 records found for CM Flashlight (Compass, SOS)
# Targeted metric value: 166367
# Processing 2 records found for Moovit: Bus Time & Train Time Live Info
# Targeted metric value: 617477
# Processing 2 records found for Facebook Ads Manager
# Targeted metric value: 19051
# Processing 4 records found for Garena Free Fire
# Targeted metric value: 5534114
# Processing 2 records found for Essential Anatomy 3
# Targeted metric value: 1533
# Processing 2 records found for Hole19: Golf GPS App, Rangefinder & Scorecard
# Targeted metric value: 6106
# Processing 3 records found for STARZ
# Targeted metric value: 88185
# Processing 4 records found for Expedia Hotels, Flights & Car Rental Travel Deals
# Targeted metric value: 136633
# Processing 2 records found for Strawberry Shortcake Ice Cream Island
# Targeted metric value: 32200
# Processing 3 records found for Pixel Art: Color by Number Game
# Targeted metric value: 1125566
# Processing 2 records found for Run Sausage Run!
# Targeted metric value: 276105
# Processing 2 records found for GO Keyboard - Emoticon keyboard, Free Theme, GIF
# Targeted metric value: 2591941
# Processing 2 records found for WhatsApp Business
# Targeted metric value: 137144
# Processing 4 records found for Google Drive
# Targeted metric value: 2731211
# Processing 3 records found for Slickdeals: Coupons & Shopping
# Targeted metric value: 33599
# Processing 2 records found for SnipSnap Coupon App
# Targeted metric value: 9975
# Processing 2 records found for YouTube
# Targeted metric value: 25655305
# Processing 2 records found for Banfield Pet Health Tracker
# Targeted metric value: 1747
# Processing 6 records found for Bleacher Report: sports news, scores, & highlights
# Targeted metric value: 122283
# Processing 2 records found for Learn C++
# Targeted metric value: 73404
# Processing 2 records found for Couple - Relationship App
# Targeted metric value: 33249
# Processing 3 records found for My Talking Tom
# Targeted metric value: 14892469
# Processing 2 records found for Sudy – Meet Elite & Rich Single
# Targeted metric value: 17268
# Processing 2 records found for Block Buddy
# Targeted metric value: 15
# Processing 2 records found for Muscle Premium - Human Anatomy, Kinesiology, Bones
# Targeted metric value: 168
# Processing 2 records found for CppDroid - C/C++ IDE
# Targeted metric value: 29980
# Processing 4 records found for Hangouts
# Targeted metric value: 3419513
# Processing 2 records found for Fun Kid Racing - Motocross
# Targeted metric value: 59768
# Processing 2 records found for Harry Potter: Hogwarts Mystery
# Targeted metric value: 1107310
# Processing 3 records found for HISTORY: Watch TV Show Full Episodes & Specials
# Targeted metric value: 33387
# Processing 2 records found for Smart Launcher 5
# Targeted metric value: 512106
# Processing 2 records found for Flickr
# Targeted metric value: 251951
# Processing 3 records found for Elmo Calls by Sesame Street
# Targeted metric value: 6903
# Processing 5 records found for Calorie Counter - MyFitnessPal
# Targeted metric value: 1873523
# Processing 2 records found for realestate.com.au - Buy, Rent & Sell Property
# Targeted metric value: 14657
# Processing 5 records found for Wish - Shopping Made Fun
# Targeted metric value: 6212081
# Processing 2 records found for Christian Dating For Free App
# Targeted metric value: 8723
# Processing 3 records found for Facetune - For Free
# Targeted metric value: 49553
# Processing 2 records found for FIFA - Tournaments, Soccer News & Live Scores
# Targeted metric value: 342912
# Processing 4 records found for Google Pay
# Targeted metric value: 348132
# Processing 3 records found for QuickBooks Accounting: Invoicing & Expenses
# Targeted metric value: 23175
# Processing 3 records found for MX Player
# Targeted metric value: 6474672
# Processing 4 records found for Shutterfly: Free Prints, Photo Books, Cards, Gifts
# Targeted metric value: 98717
# Processing 2 records found for AnatomyMapp
# Targeted metric value: 80
# Processing 2 records found for Google Analytics
# Targeted metric value: 78662
# Processing 2 records found for Jewels Star: OZ adventure
# Targeted metric value: 21892
# Processing 2 records found for Jurassic World™ Alive
# Targeted metric value: 309176
# Processing 3 records found for Daily Yoga - Yoga Fitness Plans
# Targeted metric value: 70769
# Processing 2 records found for Golfshot: Golf GPS + Tee Times
# Targeted metric value: 7543
# Processing 2 records found for AAFP
# Targeted metric value: 63
# Processing 4 records found for ZEDGE™ Ringtones & Wallpapers
# Targeted metric value: 6466641
# Processing 2 records found for Six Pack in 30 Days - Abs Workout
# Targeted metric value: 272337
# Processing 3 records found for Adobe Acrobat Reader
# Targeted metric value: 3016305
# Processing 3 records found for Google Allo
# Targeted metric value: 347086
# Processing 2 records found for HelloTalk — Chat, Speak & Learn Foreign Languages
# Targeted metric value: 84311
# Processing 9 records found for ROBLOX
# Targeted metric value: 4450890
# Processing 2 records found for MouseMingle
# Targeted metric value: 3
# Processing 2 records found for Calm - Meditate, Sleep, Relax
# Targeted metric value: 111455
# Processing 3 records found for BET NOW - Watch Shows
# Targeted metric value: 14807
# Processing 2 records found for Disney Magic Kingdoms: Build Your Own Magical Park
# Targeted metric value: 472584
# Processing 2 records found for US Open Tennis Championships 2018
# Targeted metric value: 9971
# Processing 2 records found for Calculator
# Targeted metric value: 40770
# Processing 2 records found for Metal Soldiers 2
# Targeted metric value: 153649
# Processing 2 records found for Univision NOW - Live TV and On Demand
# Targeted metric value: 22998
# Processing 2 records found for Mobile Doc Scanner (MDScan) Lite
# Targeted metric value: 46505
# Processing 2 records found for Weight Loss Tracker - RecStyle
# Targeted metric value: 20547
# Processing 2 records found for Fallout Shelter
# Targeted metric value: 2721923
# Processing 3 records found for Google Ads
# Targeted metric value: 29331
# Processing 2 records found for LinkedIn
# Targeted metric value: 1225367
# Processing 3 records found for VH1
# Targeted metric value: 27424
# Processing 2 records found for Muzy - Share photos & collages
# Targeted metric value: 70189
# Processing 2 records found for Ebook Reader
# Targeted metric value: 85842
# Processing 2 records found for Relax Meditation: Sleep with Sleep Sounds
# Targeted metric value: 26540
# Processing 2 records found for Lynda - Online Training Videos
# Targeted metric value: 8599
# Processing 2 records found for Photo Editor
# Targeted metric value: 114680
# Processing 2 records found for Free Dating App - Meet Local Singles - Flirt Chat
# Targeted metric value: 825
# Processing 4 records found for Badoo - Free Chat & Dating App
# Targeted metric value: 3781770
# Processing 2 records found for Motorola FM Radio
# Targeted metric value: 54815
# Processing 7 records found for ESPN
# Targeted metric value: 521140
# Processing 4 records found for Groupon - Shop Deals, Discounts & Coupons
# Targeted metric value: 1371082
# Processing 3 records found for Video Editor
# Targeted metric value: 159622
# Processing 2 records found for Google Sheets
# Targeted metric value: 496399
# Processing 2 records found for MARVEL Contest of Champions
# Targeted metric value: 2468915
# Processing 2 records found for No Crop & Square for Instagram
# Targeted metric value: 819774
# Processing 3 records found for Amazon Shopping
# Targeted metric value: 909226
# Processing 3 records found for Flipboard: News For Our Time
# Targeted metric value: 1284018
# Processing 3 records found for KakaoTalk: Free Calls & Text
# Targeted metric value: 2546549
# Processing 3 records found for QuickPic - Photo Gallery with Google Drive Support
# Targeted metric value: 847159
# Processing 2 records found for Asana: organize team projects
# Targeted metric value: 20815
# Processing 2 records found for Messages, Text and Video Chat for Messenger
# Targeted metric value: 49580
# Processing 2 records found for DEER HUNTER 2018
# Targeted metric value: 955656
# Processing 2 records found for Textgram - write on photos
# Targeted metric value: 295237
# Processing 2 records found for Manga AZ - Manga Comic Reader
# Targeted metric value: 126
# Processing 2 records found for Calorie Counter & Diet Tracker
# Targeted metric value: 32606
# Processing 2 records found for ooVoo Video Calls, Messaging & Stories
# Targeted metric value: 1157004
# Processing 2 records found for Flipkart Online Shopping App
# Targeted metric value: 6012719
# Processing 2 records found for Food Calorie Calculator
# Targeted metric value: 1324
# Processing 2 records found for Relax Melodies: Sleep Sounds
# Targeted metric value: 233243
# Processing 3 records found for Telegram
# Targeted metric value: 3128611
# Processing 2 records found for Geometry Dash World
# Targeted metric value: 760628
# Processing 2 records found for Zillow: Find Houses for Sale & Apartments for Rent
# Targeted metric value: 417907
# Processing 2 records found for DINO HUNTER: DEADLY SHORES
# Targeted metric value: 1381820
# Processing 2 records found for AP Mobile - Breaking News
# Targeted metric value: 76677
# Processing 2 records found for FP Notebook
# Targeted metric value: 410
# Processing 2 records found for Peak – Brain Games & Training
# Targeted metric value: 272321
# Processing 2 records found for Modcloth – Unique Indie Women's Fashion & Style
# Targeted metric value: 5121
# Processing 2 records found for Newsroom: News Worth Sharing
# Targeted metric value: 201737
# Processing 2 records found for TO-FU Oh!SUSHI
# Targeted metric value: 59917
# Processing 2 records found for Traffic Racer
# Targeted metric value: 5387781
# Processing 2 records found for Uber
# Targeted metric value: 4928420
# Processing 2 records found for ColorNote Notepad Notes
# Targeted metric value: 2401017
# Processing 4 records found for Nike+ Run Club
# Targeted metric value: 708753
# Processing 2 records found for Walmart
# Targeted metric value: 441473
# Processing 2 records found for 420 BZ Budeze Delivery
# Targeted metric value: 2
# Processing 2 records found for FilterGrid - Cam&Photo Editor
# Targeted metric value: 126338
# Processing 2 records found for Thomas & Friends: Race On!
# Targeted metric value: 29319
# Processing 2 records found for 365Scores - Live Scores
# Targeted metric value: 666521
# Processing 2 records found for Overstock – Home Decor, Furniture Shopping
# Targeted metric value: 25719
# Processing 2 records found for Camera FV-5
# Targeted metric value: 16320
# Processing 4 records found for Snapchat
# Targeted metric value: 17015352
# Processing 3 records found for Toon Blast
# Targeted metric value: 1351771
# Processing 2 records found for Polaris Office - Word, Docs, Sheets, Slide, PDF
# Targeted metric value: 549900
# Processing 2 records found for LiveMe - Video chat, new friends, and make money
# Targeted metric value: 457197
# Processing 4 records found for My Talking Angela
# Targeted metric value: 9883367
# Processing 2 records found for Moneycontrol – Stocks, Sensex, Mutual Funds, IPO
# Targeted metric value: 281635
# Processing 2 records found for Wells Fargo Mobile
# Targeted metric value: 250719
# Processing 2 records found for Amazon Kindle
# Targeted metric value: 814151
# Processing 2 records found for Microsoft Outlook
# Targeted metric value: 3252896
# Processing 2 records found for Sago Mini Babies
# Targeted metric value: 253
# Processing 2 records found for LINE Camera - Photo editor
# Targeted metric value: 1517395
# Processing 2 records found for Google
# Targeted metric value: 8033493
# Processing 2 records found for Microsoft OneDrive
# Targeted metric value: 1038306
# Processing 3 records found for Box
# Targeted metric value: 159872
# Processing 2 records found for 10 Best Foods for You
# Targeted metric value: 2490
# Processing 2 records found for BBW Dating & Curvy Singles Chat- LargeFriends
# Targeted metric value: 218
# Processing 2 records found for Best Fiends - Free Puzzle Game
# Targeted metric value: 1480189
# Processing 2 records found for Jaumo Dating, Flirt & Live Video
# Targeted metric value: 900064
# Processing 2 records found for MealLogger-Photo Food Journal
# Targeted metric value: 217
# Processing 3 records found for Weight Loss Running by Verv
# Targeted metric value: 27396
# Processing 2 records found for Earn to Die 2
# Targeted metric value: 1327269
# Processing 3 records found for ES File Explorer File Manager
# Targeted metric value: 5383985
# Processing 2 records found for Meet4U - Chat, Love, Singles!
# Targeted metric value: 40039
# Processing 2 records found for RULES OF SURVIVAL
# Targeted metric value: 1343866
# Processing 2 records found for Redfin Real Estate
# Targeted metric value: 36857
# Processing 2 records found for Ada - Your Health Guide
# Targeted metric value: 87418
# Processing 2 records found for H TV
# Targeted metric value: 103078
# Processing 2 records found for AdWords Express
# Targeted metric value: 7149
# Processing 2 records found for Dungeon Hunter Champions: Epic Online Action RPG
# Targeted metric value: 26307
# Processing 2 records found for Camera FV-5 Lite
# Targeted metric value: 130081
# Processing 2 records found for Photo Editor Selfie Camera Filter & Mirror Image
# Targeted metric value: 527248
# Processing 2 records found for Live Girls Talk - Free Video Chat
# Targeted metric value: 125
# Processing 2 records found for Plants vs. Zombies™ Heroes
# Targeted metric value: 379415
# Processing 2 records found for Fabulous: Motivate Me! Meditate, Relax, Sleep
# Targeted metric value: 205299
# Processing 3 records found for Cardiac diagnosis (heart rate, arrhythmia)
# Targeted metric value: 4559
# Processing 3 records found for Google Chrome: Fast & Secure
# Targeted metric value: 9643041
# Processing 3 records found for Extreme Coupon Finder
# Targeted metric value: 11798
# Processing 2 records found for Howlr
# Targeted metric value: 105
# Processing 6 records found for Bowmasters
# Targeted metric value: 1536349
# Processing 3 records found for Tubi TV - Free Movies & TV
# Targeted metric value: 296829
# Processing 2 records found for 1800 Contacts - Lens Store
# Targeted metric value: 23160
# Processing 3 records found for Papumba Academy - Fun Learning For Kids
# Targeted metric value: 496
# Processing 3 records found for Gmail
# Targeted metric value: 4604483
# Processing 3 records found for Weight Watchers Mobile
# Targeted metric value: 270294
# Processing 3 records found for Chick-fil-A
# Targeted metric value: 28009
# Processing 5 records found for TripAdvisor Hotels Flights Restaurants Attractions
# Targeted metric value: 1162838
# Processing 2 records found for NOOK: Read eBooks & Magazines
# Targeted metric value: 155466
# Processing 4 records found for Clash Royale
# Targeted metric value: 23136735
# Processing 2 records found for Mapy.cz - Cycling & Hiking offline maps
# Targeted metric value: 56443
# Processing 2 records found for BuzzFeed: News, Tasty, Quizzes
# Targeted metric value: 131028
# Processing 2 records found for Pokémon GO
# Targeted metric value: 10424925
# Processing 2 records found for High Blood Pressure Symptoms
# Targeted metric value: 531
# Processing 3 records found for Nike Training Club - Workouts & Fitness Plans
# Targeted metric value: 251618
# Processing 2 records found for Idle Heroes
# Targeted metric value: 417197
# Processing 2 records found for Z Camera - Photo Editor, Beauty Selfie, Collage
# Targeted metric value: 1075277
# Processing 2 records found for English Grammar Test
# Targeted metric value: 104676
# Processing 3 records found for OkCupid Dating
# Targeted metric value: 285838
# Processing 2 records found for Hello Kitty Nail Salon
# Targeted metric value: 369378
# Processing 4 records found for Wordscapes
# Targeted metric value: 230849
# Processing 3 records found for Yahoo Mail – Stay Organized
# Targeted metric value: 4188345
# Processing 3 records found for Slack
# Targeted metric value: 51510
# Processing 2 records found for Flashlight
# Targeted metric value: 162335
# Processing 2 records found for PayPal
# Targeted metric value: 659760
# Processing 2 records found for School of Dragons
# Targeted metric value: 530792
# Processing 2 records found for Quora
# Targeted metric value: 313633
# Processing 2 records found for DreamWorks Friends
# Targeted metric value: 1042
# Processing 2 records found for Anthem BC Anywhere
# Targeted metric value: 496
# Processing 2 records found for Twitch: Livestream Multiplayer Games & Esports
# Targeted metric value: 2133296
# Processing 5 records found for BeautyPlus - Easy Photo Editor & Selfie Camera
# Targeted metric value: 3158151
# Processing 2 records found for Carousell: Snap-Sell, Chat-Buy
# Targeted metric value: 125783
# Processing 3 records found for FOX NOW - On Demand & Live TV
# Targeted metric value: 60841
# Processing 2 records found for MyPlate Calorie Tracker
# Targeted metric value: 24094
# Processing 3 records found for KAYAK Flights, Hotels & Cars
# Targeted metric value: 216388
# Processing 2 records found for Shadow Fight 2
# Targeted metric value: 10981850
# Processing 3 records found for HotelTonight: Book amazing deals at great hotels
# Targeted metric value: 57573
# Processing 3 records found for Fishdom
# Targeted metric value: 2158580
# Processing 2 records found for wetter.com - Weather and Radar
# Targeted metric value: 189313
# Processing 2 records found for Fantasy Football
# Targeted metric value: 50179
# Processing 3 records found for Human Anatomy Atlas 2018: Complete 3D Human Body
# Targeted metric value: 2923
# Processing 2 records found for Wattpad 📖 Free Books
# Targeted metric value: 2915189
# Processing 2 records found for Kids Balloon Pop Game Free 🎈
# Targeted metric value: 38021
# Processing 2 records found for Home Security Camera WardenCam - reuse old phones
# Targeted metric value: 43847
# Processing 2 records found for Cartoon Network App
# Targeted metric value: 119202
# Processing 2 records found for Etsy: Handmade & Vintage Goods
# Targeted metric value: 95520
# Processing 2 records found for Farming Simulator 14
# Targeted metric value: 530904
# Processing 2 records found for Waze - GPS, Maps, Traffic Alerts & Live Navigation
# Targeted metric value: 7232629
# Processing 2 records found for Runtastic Sleep Better: Sleep Cycle & Smart Alarm
# Targeted metric value: 111465
# Processing 3 records found for LINE: Free Calls & Messages
# Targeted metric value: 10790289
# Processing 2 records found for Ruler
# Targeted metric value: 27180
# Processing 2 records found for Cache Cleaner-DU Speed Booster (booster & cleaner)
# Targeted metric value: 12759815
# Processing 5 records found for Flow Free
# Targeted metric value: 1295625
# Processing 2 records found for Fruits Bomb
# Targeted metric value: 74695
# Processing 2 records found for E*TRADE Mobile
# Targeted metric value: 10658
# Processing 2 records found for Chat Kids - Chat Room For Kids
# Targeted metric value: 6
# Processing 2 records found for Acorns - Invest Spare Change
# Targeted metric value: 45962
# Processing 4 records found for The CW
# Targeted metric value: 288209
# Processing 2 records found for Calorie Counter - MyNetDiary
# Targeted metric value: 27439
# Processing 2 records found for Health and Nutrition Guide
# Targeted metric value: 7895
# Processing 2 records found for Grubhub: Food Delivery
# Targeted metric value: 155944
# Processing 2 records found for Turbo FAST
# Targeted metric value: 1329192
# Processing 2 records found for Apartment List: Housing, Apt, and Property Rentals
# Targeted metric value: 8481
# Processing 2 records found for AC - Tips & News for Android™
# Targeted metric value: 23292
# Processing 2 records found for Yandex Browser with Protect
# Targeted metric value: 1237135
# Processing 2 records found for Animal Jam - Play Wild!
# Targeted metric value: 361970
# Processing 2 records found for Flipp - Weekly Shopping
# Targeted metric value: 85858
# Processing 2 records found for Free Dating App - YoCutie - Flirt, Chat & Meet
# Targeted metric value: 97699
# Processing 2 records found for Blood Pressure Monitor
# Targeted metric value: 17
# Processing 2 records found for ASCCP Mobile
# Targeted metric value: 63
# Processing 4 records found for AliExpress - Smarter Shopping, Better Living
# Targeted metric value: 5917485
# Processing 2 records found for Weather by eltiempo.es
# Targeted metric value: 67854
# Processing 2 records found for Newegg Mobile
# Targeted metric value: 35497
# Processing 2 records found for Meditation Music - Relax, Yoga
# Targeted metric value: 48226
# Processing 2 records found for Stocard - Rewards Cards Wallet
# Targeted metric value: 284725
# Processing 2 records found for Penn State Health OnDemand
# Targeted metric value: 0
# Processing 2 records found for Pedi STAT
# Targeted metric value: 129
# Processing 2 records found for Learn English with Wlingua
# Targeted metric value: 314300
# Processing 4 records found for Quizlet: Learn Languages & Vocab with Flashcards
# Targeted metric value: 211856
# Processing 2 records found for Final Fantasy XV: A New Empire
# Targeted metric value: 484981
# Processing 2 records found for Poshmark - Buy & Sell Fashion
# Targeted metric value: 46153
# Processing 3 records found for Google Voice
# Targeted metric value: 171052
# Processing 2 records found for Google Street View
# Targeted metric value: 2129707
# Processing 2 records found for RT 516 VET
# Targeted metric value: 0
# Processing 3 records found for YouCam Perfect - Selfie Photo Editor
# Targeted metric value: 1579343
# Processing 2 records found for Docs To Go™ Free Office Suite
# Targeted metric value: 217730
# Processing 2 records found for SHOWTIME
# Targeted metric value: 12398
# Processing 2 records found for Black White Interracial Dating - Interracial Match
# Targeted metric value: 537
# Processing 3 records found for MARVEL Strike Force
# Targeted metric value: 166312
# Processing 2 records found for I’m Expecting - Pregnancy App
# Targeted metric value: 71269
# Processing 2 records found for FOX Sports: Live Streaming, Scores & News
# Targeted metric value: 28895
# Processing 2 records found for Sway Medical
# Targeted metric value: 3
# Processing 3 records found for Camera360: Selfie Photo Editor with Funny Sticker
# Targeted metric value: 4865132
# Processing 3 records found for Text Free: WiFi Calling App
# Targeted metric value: 83488
# Processing 2 records found for InstaBeauty -Makeup Selfie Cam
# Targeted metric value: 654419
# Processing 2 records found for Cardboard
# Targeted metric value: 130287
# Processing 2 records found for AccuWeather: Daily Forecast & Live Weather Reports
# Targeted metric value: 2053404
# Processing 2 records found for Angry Birds 2
# Targeted metric value: 3883589
# Processing 4 records found for A&E - Watch Full Episodes of TV Shows
# Targeted metric value: 29708
# Processing 3 records found for BBW Dating & Plus Size Chat
# Targeted metric value: 12633
# Processing 2 records found for NOOK App for NOOK Devices
# Targeted metric value: 19090
# Processing 2 records found for Reuters News
# Targeted metric value: 13169
# Processing 3 records found for Crunchyroll - Everything Anime
# Targeted metric value: 310095
# Processing 2 records found for Wheretoget: Shop in style
# Targeted metric value: 6808
# Processing 2 records found for Facebook Lite
# Targeted metric value: 8606259
# Processing 2 records found for CM Browser - Ad Blocker , Fast Download , Privacy
# Targeted metric value: 2265084
# Processing 3 records found for POF Free Dating App
# Targeted metric value: 1175815
# Processing 2 records found for InstaSize Photo Filters & Collage Editor
# Targeted metric value: 811714
# Processing 3 records found for Dog Run - Pet Dog Simulator
# Targeted metric value: 48701
# Processing 2 records found for Zara
# Targeted metric value: 95905
# Processing 2 records found for Monash Uni Low FODMAP Diet
# Targeted metric value: 1135
# Processing 2 records found for Shopkick: Free Gift Cards, Shop Rewards & Deals
# Targeted metric value: 213735
# Processing 3 records found for Khan Academy
# Targeted metric value: 85375
# Processing 2 records found for Trulia Real Estate & Rentals
# Targeted metric value: 175293
# Processing 2 records found for Fandango Movies - Times + Tickets
# Targeted metric value: 243747
# Processing 2 records found for EMT-B Pocket Prep
# Targeted metric value: 2951
# Processing 3 records found for Blood Pressure
# Targeted metric value: 33033
# Processing 2 records found for Chispa, the Dating App for Latino, Latina Singles
# Targeted metric value: 4195
# Processing 4 records found for Instagram
# Targeted metric value: 66577446
# Processing 2 records found for Tagged - Meet, Chat & Dating
# Targeted metric value: 486830
# Processing 2 records found for Capital One® Mobile
# Targeted metric value: 510401
# Processing 6 records found for Temple Run 2
# Targeted metric value: 8119154
# Processing 6 records found for Sniper 3D Gun Shooter: Free Shooting Games - FPS
# Targeted metric value: 7674252
# Processing 4 records found for DRAGON BALL LEGENDS
# Targeted metric value: 338742
# Processing 5 records found for Yahoo Fantasy Sports - #1 Rated Fantasy App
# Targeted metric value: 277939
# Processing 3 records found for NYTimes - Latest News
# Targeted metric value: 63647
# Processing 2 records found for Photo Editor-
# Targeted metric value: 68071
# Processing 2 records found for Cardi B Live Stream Video Chat - Prank
# Targeted metric value: 28
# Processing 2 records found for Google Duo - High Quality Video Calls
# Targeted metric value: 2083237
# Processing 2 records found for CT Scan Cross Sectional Anatomy
# Targeted metric value: 10
# Processing 6 records found for slither.io
# Targeted metric value: 5235294
# Processing 2 records found for Calorie Counter by FatSecret
# Targeted metric value: 229214
# Processing 2 records found for Blood Pressure(BP) Diary
# Targeted metric value: 3596
# Processing 2 records found for Moco+ - Chat, Meet People
# Targeted metric value: 1546
# Processing 2 records found for Oxford Dictionary of English : Free
# Targeted metric value: 364452
# Processing 3 records found for Open Camera
# Targeted metric value: 116880
# Processing 2 records found for Messenger Lite: Free Calls & Messages
# Targeted metric value: 1429038
# Processing 2 records found for Nighty Night Circus
# Targeted metric value: 382
# Processing 2 records found for Daily Manga - Comic & Webtoon
# Targeted metric value: 1462
# Processing 2 records found for FotMob - Live Soccer Scores
# Targeted metric value: 410395
# Processing 3 records found for Hungry Shark Evolution
# Targeted metric value: 6074627
# Processing 3 records found for Just She - Top Lesbian Dating
# Targeted metric value: 954
# Processing 2 records found for TurboScan: scan documents and receipts in PDF
# Targeted metric value: 11442
# Processing 2 records found for Chess Free
# Targeted metric value: 1375988
# Processing 2 records found for G Cloud Backup
# Targeted metric value: 267189
# Processing 4 records found for Google Keep
# Targeted metric value: 691474
# Processing 3 records found for Fancy
# Targeted metric value: 39735
# Processing 2 records found for Realtor.com Real Estate: Homes for Sale and Rent
# Targeted metric value: 162243
# Processing 2 records found for Gay Sugar Daddy Dating & Hookup – Sudy Gay
# Targeted metric value: 2212
# Processing 2 records found for 21-Day Meditation Experience
# Targeted metric value: 11506
# Processing 2 records found for Coursera: Online courses
# Targeted metric value: 90481
# Processing 3 records found for Lose It! - Calorie Counter
# Targeted metric value: 69395
# Processing 2 records found for My Diet Diary Calorie Counter
# Targeted metric value: 18539
# Processing 3 records found for USA TODAY
# Targeted metric value: 49259
# Processing 2 records found for Girls Live Chat - Free Text & Video Chat
# Targeted metric value: 110
# Processing 2 records found for Honkai Impact 3rd
# Targeted metric value: 59017
# Processing 2 records found for CBS - Full Episodes & Live TV
# Targeted metric value: 92058
# Processing 2 records found for Blood Pressure Companion
# Targeted metric value: 178
# Processing 2 records found for Cheapflights – Flight Search
# Targeted metric value: 47780
# Processing 2 records found for Sounds for Toddlers FREE
# Targeted metric value: 6190
# Processing 3 records found for Quick PDF Scanner + OCR FREE
# Targeted metric value: 80805
# Processing 2 records found for Digit Save Money Automatically
# Targeted metric value: 8188
# Processing 2 records found for CallApp: Caller ID, Blocker & Phone Call Recorder
# Targeted metric value: 483782
# Processing 3 records found for WhatsApp Messenger
# Targeted metric value: 69119316
# Processing 2 records found for Headspace: Meditation & Mindfulness
# Targeted metric value: 77563
# Processing 2 records found for LOVOO
# Targeted metric value: 852455
# Processing 6 records found for Zombie Catchers
# Targeted metric value: 990796
# Processing 5 records found for theScore: Live Sports Scores, News, Stats & Videos
# Targeted metric value: 133833
# Processing 2 records found for UNICORN - Color By Number & Pixel Art Coloring
# Targeted metric value: 8264
# Processing 2 records found for Hostelworld: Hostels & Cheap Hotels Travel App
# Targeted metric value: 17878
# Processing 2 records found for Hospitalist Handbook
# Targeted metric value: 12
# Processing 2 records found for Zello PTT Walkie Talkie
# Targeted metric value: 695613
# Processing 2 records found for Invoice & Time Tracking - Zoho
# Targeted metric value: 5800
# Processing 2 records found for Dunkin' Donuts
# Targeted metric value: 68270
# Processing 2 records found for The Sims™ FreePlay
# Targeted metric value: 931595
# Processing 2 records found for Once - Quality Matches Every day
# Targeted metric value: 222888
# Processing 2 records found for EMT PASS
# Targeted metric value: 51
# Processing 2 records found for SignEasy | Sign and Fill PDF and other Documents
# Targeted metric value: 8978
# Processing 2 records found for CM Locker - Security Lockscreen
# Targeted metric value: 3090727
# Processing 3 records found for Strawberry Shortcake BerryRush
# Targeted metric value: 525552
# Processing 2 records found for Face Filter, Selfie Editor - Sweet Camera
# Targeted metric value: 142758
# Processing 2 records found for Free Cam Girls - Live Webcam
# Targeted metric value: 35
# Processing 2 records found for Amazon for Tablets
# Targeted metric value: 141613
# Processing 2 records found for letgo: Buy & Sell Used Stuff, Cars & Real Estate
# Targeted metric value: 973270
# Processing 2 records found for JH Blood Pressure Monitor
# Targeted metric value: 9
# Processing 3 records found for trivago: Hotels & Travel
# Targeted metric value: 219848
# Processing 2 records found for VPN Free - Betternet Hotspot VPN & Private Browser
# Targeted metric value: 801054
# Processing 2 records found for Free Dating Hook Up Messenger
# Targeted metric value: 1157
# Processing 3 records found for Dream League Soccer 2018
# Targeted metric value: 9883806
# Processing 2 records found for HBO GO: Stream with TV Package
# Targeted metric value: 87734
# Processing 3 records found for Fashion in Vogue
# Targeted metric value: 1797
# Processing 2 records found for Who
# Targeted metric value: 2451093
# Processing 3 records found for Sago Mini Friends
# Targeted metric value: 13155
# Processing 2 records found for Offline Maps & Navigation
# Targeted metric value: 193364
# Processing 2 records found for SKOUT - Meet, Chat, Go Live
# Targeted metric value: 1064076
# Processing 2 records found for No.Draw - Colors by Number 2018
# Targeted metric value: 235906
# Processing 2 records found for SUBWAY®
# Targeted metric value: 21381
# Processing 3 records found for Udemy - Online Courses
# Targeted metric value: 99020
# Processing 2 records found for Blendr - Chat, Flirt & Meet
# Targeted metric value: 28671
# Processing 4 records found for Meetup
# Targeted metric value: 79130
# Processing 2 records found for Whoscall - Caller ID & Block
# Targeted metric value: 552635
# Processing 3 records found for Microsoft OneNote
# Targeted metric value: 480643
# Processing 2 records found for WWE
# Targeted metric value: 736864
# Processing 2 records found for Monster High™
# Targeted metric value: 66661
# Processing 3 records found for Mint: Budget, Bills, Finance
# Targeted metric value: 129305
# Processing 2 records found for CNBC: Breaking Business News & Live Market Data
# Targeted metric value: 24666
# Processing 2 records found for Topbuzz: Breaking News, Videos & Funny GIFs
# Targeted metric value: 175110
# Processing 4 records found for Clash of Clans
# Targeted metric value: 44893888
# Processing 2 records found for Super ABC! Learning games for kids! Preschool apps
# Targeted metric value: 20267
# Processing 2 records found for Share Music & Transfer Files - Xender
# Targeted metric value: 1280423
# Processing 2 records found for Paramedic Protocol Provider
# Targeted metric value: 171
# Processing 2 records found for FastMeet: Chat, Dating, Love
# Targeted metric value: 22545
# Processing 2 records found for Toca Life: City
# Targeted metric value: 31100
# Processing 2 records found for Lark - 24/7 Health Coach
# Targeted metric value: 3405
# Processing 2 records found for Robinhood - Investing, No Fees
# Targeted metric value: 57493
# Processing 2 records found for Knife Hit
# Targeted metric value: 462614
# Processing 4 records found for DC Super Hero Girls™
# Targeted metric value: 43090
# Processing 2 records found for MoodSpace
# Targeted metric value: 503
# Processing 2 records found for Live Talk - Free Text and Video Chat
# Targeted metric value: 185
# Processing 6 records found for Helix Jump
# Targeted metric value: 1500999
# Processing 2 records found for Dating App, Flirt & Chat : W-Match
# Targeted metric value: 175722
# Processing 2 records found for Red Bull TV: Live Sports, Music & Entertainment
# Targeted metric value: 42069
# Processing 3 records found for Gboard - the Google Keyboard
# Targeted metric value: 1859115
# Processing 2 records found for Who Viewed My Facebook Profile - Stalkers Visitors
# Targeted metric value: 273244
# Processing 2 records found for fred's Pharmacy
# Targeted metric value: 315
# Processing 2 records found for Call Blocker
# Targeted metric value: 188841
# Processing 2 records found for Cougar Dating Life : Date Older Women Sugar Mummy
# Targeted metric value: 1645
# Processing 2 records found for Money Lover: Expense Tracker, Budget Planner
# Targeted metric value: 126447
# Processing 4 records found for Google Photos
# Targeted metric value: 10859051
# Processing 2 records found for Socratic - Math Answers & Homework Help
# Targeted metric value: 37862
# Processing 2 records found for BBC Sport
# Targeted metric value: 18679
# Processing 2 records found for Tee and Mo Bath Time Free
# Targeted metric value: 418
# Processing 3 records found for Tumblr
# Targeted metric value: 2955326
# Processing 2 records found for Insightly CRM
# Targeted metric value: 1383
# Processing 3 records found for Apex Launcher
# Targeted metric value: 266434
# Processing 6 records found for Nick
# Targeted metric value: 123322
# Processing 4 records found for Google News
# Targeted metric value: 878065
# Processing 2 records found for FreshBooks Classic
# Targeted metric value: 1802
# Processing 2 records found for Find Real Love — YouLove Premium Dating
# Targeted metric value: 212626
# Processing 3 records found for Youper - AI Therapy
# Targeted metric value: 2014
# Processing 2 records found for FlirtChat - ♥Free Dating/Flirting App♥
# Targeted metric value: 2433
# Processing 2 records found for Mortgage by Zillow: Calculator & Rates
# Targeted metric value: 4435
# Processing 2 records found for C Programming
# Targeted metric value: 22251
# Processing 2 records found for Calorie Counter - Macros
# Targeted metric value: 3061
# Processing 3 records found for Camera for Android
# Targeted metric value: 240475
# Processing 2 records found for PlayKids - Educational cartoons and games for kids
# Targeted metric value: 182173
# Processing 4 records found for PUBG MOBILE
# Targeted metric value: 3716278
# Processing 2 records found for Beautiful Widgets Free
# Targeted metric value: 25037
# Processing 2 records found for Clover Dating App
# Targeted metric value: 11633
# Processing 2 records found for TickTick: To Do List with Reminder, Day Planner
# Targeted metric value: 25370
# Processing 2 records found for Video Player All Format
# Targeted metric value: 259003
# Processing 3 records found for Any.do: To-do list, Calendar, Reminders & Planner
# Targeted metric value: 298854
# Processing 2 records found for Text free - Free Text + Call
# Targeted metric value: 315441
# Processing 2 records found for HD Camera for Android
# Targeted metric value: 351255
# Processing 2 records found for The NBC App - Watch Live TV and Full Episodes
# Targeted metric value: 58104
# Processing 2 records found for Blur Image Background
# Targeted metric value: 129272
# Processing 2 records found for Nova Launcher
# Targeted metric value: 1121805
# Processing 3 records found for DisneyNOW – TV Shows & Games
# Targeted metric value: 82499
# Processing 2 records found for Wendy’s – Food and Offers
# Targeted metric value: 6512
# Processing 3 records found for Crackle - Free TV & Movies
# Targeted metric value: 388089
# Processing 2 records found for ASOS
# Targeted metric value: 181823
# Processing 2 records found for Runkeeper - GPS Track Run Walk
# Targeted metric value: 501144
# Processing 2 records found for Ovia Fertility Tracker & Ovulation Calculator
# Targeted metric value: 53747
# Processing 3 records found for Frozen Free Fall
# Targeted metric value: 1574546
# Processing 2 records found for Talkatone: Free Texts, Calls & Phone Number
# Targeted metric value: 132015
# Processing 4 records found for Minion Rush: Despicable Me Official Game
# Targeted metric value: 10216997
# Processing 2 records found for MTV
# Targeted metric value: 35279
# Processing 2 records found for Princess Coloring Book
# Targeted metric value: 9779
# Processing 2 records found for Color by Number – New Coloring Book
# Targeted metric value: 142308
# Processing 4 records found for Hill Climb Racing
# Targeted metric value: 8923847
# Processing 2 records found for Do It Later: Tasks & To-Dos
# Targeted metric value: 123412
# Processing 3 records found for BBC News
# Targeted metric value: 296781
# Processing 2 records found for Transenger – Ts Dating and Chat for Free
# Targeted metric value: 8
# Processing 3 records found for Dropbox
# Targeted metric value: 1861310
# Processing 2 records found for Orbitz - Hotels, Flights & Package Deals
# Targeted metric value: 33256
# Processing 2 records found for ABC News - US & World News
# Targeted metric value: 18976
# Processing 2 records found for PowerDirector Video Editor App: 4K, Slow Mo & More
# Targeted metric value: 714665
# Processing 7 records found for Duolingo: Learn Languages Free
# Targeted metric value: 6297590
# Processing 3 records found for Microsoft Word
# Targeted metric value: 2084126
# Processing 3 records found for Food Network
# Targeted metric value: 7823
# ...
# Processing 2 records found for English Dictionary - Offline
# Targeted metric value: 341234
# Processing 2 records found for TextNow - free text + calls
# Targeted metric value: 441189
# Processing 5 records found for Zombie Tsunami
# Targeted metric value: 4921451
# Processing 2 records found for EMT Review Plus
# Targeted metric value: 199
# Processing 2 records found for YouCam Makeup - Magic Selfie Makeovers
# Targeted metric value: 3337956
# Processing 2 records found for The Emirates App
# Targeted metric value: 22776
# Processing 2 records found for Colorfy: Coloring Book for Adults - Free
# Targeted metric value: 787177
# Processing 4 records found for TED
# Targeted metric value: 181961
# Processing 2 records found for Baby Panda Care
# Targeted metric value: 108795
# Processing 5 records found for MLB At Bat
# Targeted metric value: 82883
# Processing 2 records found for Invoice 2go — Professional Invoices and Estimates
# Targeted metric value: 16422
# Processing 2 records found for Seven - 7 Minute Workout Training Challenge
# Targeted metric value: 75571
# Processing 3 records found for Google My Business
# Targeted metric value: 70991
# Processing 2 records found for McDonald's
# Targeted metric value: 145646
# Processing 2 records found for Chat Rooms, Avatars, Date - Galaxy
# Targeted metric value: 135420
# Processing 2 records found for K PLUS
# Targeted metric value: 124424
# Processing 2 records found for Maps & GPS Navigation — OsmAnd
# Targeted metric value: 60838
# Processing 3 records found for Viki: Asian TV Dramas & Movies
# Targeted metric value: 407719
# Processing 2 records found for NBC News
# Targeted metric value: 63020
# Processing 3 records found for RetailMeNot - Coupons, Deals & Discount Shopping
# Targeted metric value: 210208
# Processing 2 records found for Curriculum vitae App CV Builder Free Resume Maker
# Targeted metric value: 4571
# Processing 2 records found for Ringtone Maker
# Targeted metric value: 495905
# Processing 2 records found for Homescapes
# Targeted metric value: 3093932
# Processing 2 records found for BeyondMenu Food Delivery
# Targeted metric value: 51543
# Processing 3 records found for Yahoo Sports - scores, stats, news, & highlights
# Targeted metric value: 32386
# Processing 3 records found for Score! Hero
# Targeted metric value: 5419676
# Processing 2 records found for COOKING MAMA Let's Cook!
# Targeted metric value: 528917
# Processing 2 records found for Phone Tracker : Family Locator
# Targeted metric value: 231446
# Processing 3 records found for Periscope - Live Video
# Targeted metric value: 479939
# Processing 2 records found for myAT&T
# Targeted metric value: 80847
# Processing 3 records found for Candy Camera - selfie, beauty camera, photo editor
# Targeted metric value: 3368705
# Processing 3 records found for Toca Kitchen 2
# Targeted metric value: 1014846
# Processing 2 records found for Zappos – Shoe shopping made simple
# Targeted metric value: 44588
# Processing 2 records found for Planner Pro-Personal Organizer
# Targeted metric value: 10270
# Processing 3 records found for IMDb Movies & TV
# Targeted metric value: 501498
# Processing 2 records found for CMB Free Dating App
# Targeted metric value: 48845
# Processing 4 records found for Block Puzzle
# Targeted metric value: 59907
# Processing 2 records found for Domino's Pizza USA
# Targeted metric value: 1032935
# Processing 2 records found for Inside Out Thought Bubbles
# Targeted metric value: 623398
# Processing 3 records found for free video calls and chat
# Targeted metric value: 594728
# Processing 2 records found for JOANN - Crafts & Coupons
# Targeted metric value: 34802
# Processing 2 records found for Coloring book moana
# Targeted metric value: 974
# Processing 2 records found for Bubble Shooter 2
# Targeted metric value: 23043
# Processing 2 records found for CM Launcher 3D - Theme, Wallpapers, Efficient
# Targeted metric value: 6702776
# Processing 2 records found for WPS Office - Word, Docs, PDF, Note, Slide & Sheet
# Targeted metric value: 1508137
# Processing 7 records found for Candy Crush Saga
# Targeted metric value: 22430188
# Processing 3 records found for Opera Mini - fast web browser
# Targeted metric value: 5150801
# Processing 2 records found for CM FILE MANAGER HD
# Targeted metric value: 144879
# Processing 2 records found for Southwest Airlines
# Targeted metric value: 24781
# Processing 3 records found for Solitaire
# Targeted metric value: 254258
# Processing 2 records found for Hot Wheels: Race Off
# Targeted metric value: 520654
# Processing 2 records found for A Manual of Acupuncture
# Targeted metric value: 214
# Processing 2 records found for Tiny Scanner - PDF Scanner App
# Targeted metric value: 286897
# Processing 2 records found for Hill Climb Racing 2
# Targeted metric value: 2750645
# Processing 2 records found for LEGO® Juniors Create & Cruise
# Targeted metric value: 673203
# Processing 3 records found for UC Browser - Fast Download Private & Secure
# Targeted metric value: 17714850
# Processing 2 records found for Shopkins World!
# Targeted metric value: 169609
# Processing 6 records found for Subway Surfers
# Targeted metric value: 27725352
# Processing 2 records found for Scarf Fashion Designer
# Targeted metric value: 16637
# Processing 2 records found for StyleSeat
# Targeted metric value: 20304
# Processing 2 records found for Podcast App: Free & Offline Podcasts by Player FM
# Targeted metric value: 66407
# Processing 4 records found for Babbel – Learn Languages
# Targeted metric value: 267787
# Processing 5 records found for Farm Heroes Saga
# Targeted metric value: 7615646
# Processing 2 records found for EliteSingles – Dating for Single Professionals
# Targeted metric value: 5377
# Processing 2 records found for My Photo Keyboard
# Targeted metric value: 211620
# Processing 4 records found for Word Search
# Targeted metric value: 344585
# Processing 2 records found for Dude Perfect 2
# Targeted metric value: 401648
# Processing 2 records found for Premier League - Official App
# Targeted metric value: 63782
# Processing 3 records found for Target - now with Cartwheel
# Targeted metric value: 68406
# Processing 2 records found for DC Comics
# Targeted metric value: 25673
# Processing 2 records found for Crew - Free Messaging and Scheduling
# Targeted metric value: 4159
# Processing 2 records found for Free Dating & Flirt Chat - Choice of Love
# Targeted metric value: 42197
# Processing 2 records found for ZOOM Cloud Meetings
# Targeted metric value: 31614
# Processing 2 records found for Jetpack Joyride
# Targeted metric value: 4638163
# Processing 2 records found for PAC-MAN
# Targeted metric value: 685981
# Processing 2 records found for Nextdoor - Local neighborhood news & classifieds
# Targeted metric value: 51504
# Processing 2 records found for 2017 EMRA Antibiotic Guide
# Targeted metric value: 12
# Processing 2 records found for Avokiddo Emotions
# Targeted metric value: 73
# Processing 2 records found for ScriptSave WellRx Rx Discounts
# Targeted metric value: 700
# Processing 2 records found for CBS Sports Fantasy
# Targeted metric value: 43611
# Processing 2 records found for Random Video Chat App With Strangers
# Targeted metric value: 3
# Processing 5 records found for Plants vs. Zombies FREE
# Targeted metric value: 4067651
# Processing 3 records found for Gyft - Mobile Gift Card Wallet
# Targeted metric value: 9701
# Processing 2 records found for EMT Tutor NREMT-B Study Guide
# Targeted metric value: 625
# Processing 2 records found for Fast Scanner : Free PDF Scan
# Targeted metric value: 103755
# Processing 4 records found for WeChat
# Targeted metric value: 5387631
# Processing 3 records found for Miraculous Ladybug & Cat Noir - The Official Game
# Targeted metric value: 185382
# Processing 2 records found for ai.type Free Emoji Keyboard
# Targeted metric value: 647844
# Processing 2 records found for Meet24 - Love, Chat, Singles
# Targeted metric value: 57083
# Processing 3 records found for SayHi Chat, Meet New People
# Targeted metric value: 423138
# Processing 2 records found for My Dressing - Fashion closet
# Targeted metric value: 12452
# Processing 2 records found for We Heart It
# Targeted metric value: 637309
# Processing 2 records found for Crossy Road
# Targeted metric value: 4230886
# Processing 2 records found for Airbnb
# Targeted metric value: 359560
# Processing 2 records found for Showtime Anytime
# Targeted metric value: 18523
# Processing 5 records found for Netflix
# Targeted metric value: 5456708
# Processing 2 records found for Photo Editor Pro
# Targeted metric value: 1871421
# Processing 2 records found for Block Puzzle Classic Legend !
# Targeted metric value: 17044
# Processing 2 records found for PTA Content Master
# Targeted metric value: 64
# Processing 2 records found for Microsoft Excel
# Targeted metric value: 1079616
# Processing 4 records found for Learn languages, grammar & vocabulary with Memrise
# Targeted metric value: 1107948
# Processing 2 records found for Agar.io
# Targeted metric value: 3816799
# Processing 3 records found for B612 - Beauty & Filter Camera
# Targeted metric value: 5282578
# Processing 2 records found for Diabetes & Diet Tracker
# Targeted metric value: 395
# Processing 6 records found for Bubble Shooter
# Targeted metric value: 148990
# Processing 2 records found for Gardenscapes
# Targeted metric value: 4129665
# Processing 2 records found for FarmersOnly Dating
# Targeted metric value: 1146
# Processing 2 records found for Hide App, Private Dating, Safe Chat - PrivacyHider
# Targeted metric value: 35206
# Processing 5 records found for Angry Birds Classic
# Targeted metric value: 5566908
# Processing 2 records found for Episode - Choose Your Story
# Targeted metric value: 1842381
# Processing 3 records found for PJ Masks: Moonlight Heroes
# Targeted metric value: 87045
# Processing 2 records found for Pocket Yoga
# Targeted metric value: 2107
# Processing 3 records found for Runtastic Running App & Mile Tracker
# Targeted metric value: 827653
# Processing 2 records found for Fly Delta
# Targeted metric value: 27560
# Processing 4 records found for Houzz Interior Design Ideas
# Targeted metric value: 353813
# Processing 2 records found for Notepad & To do list
# Targeted metric value: 226295
# Processing 2 records found for OfficeSuite : Free Office + PDF Editor
# Targeted metric value: 1002861
# Processing 4 records found for busuu: Learn Languages - Spanish, English & More
# Targeted metric value: 207294
# Processing 4 records found for HBO NOW: Stream TV & Movies
# Targeted metric value: 61230
# Processing 2 records found for Xero Accounting Software
# Targeted metric value: 2111
# Processing 2 records found for Dictionary - Merriam-Webster
# Targeted metric value: 454412
# Processing 4 records found for Rosetta Stone: Learn to Speak & Read New Languages
# Targeted metric value: 172508
# Processing 2 records found for Super Hearing Super Ear Amplifier
# Targeted metric value: 21
# Processing 3 records found for Pinterest
# Targeted metric value: 4305441
# Processing 2 records found for Camera360 Lite - Selfie Camera
# Targeted metric value: 221878
# Processing 2 records found for Truecaller: Caller ID, SMS spam blocking & Dialer
# Targeted metric value: 7820775
# Processing 2 records found for Racing in Car 2
# Targeted metric value: 234589
# Processing 2 records found for textPlus: Free Text & Calls
# Targeted metric value: 382121
# Processing 2 records found for Web Browser for Android
# Targeted metric value: 55110
# Processing 2 records found for Chrome Beta
# Targeted metric value: 228794
# Processing 3 records found for NFL
# Targeted metric value: 459797
# Processing 4 records found for YouTube Kids
# Targeted metric value: 470713
# Processing 3 records found for Dr. Panda & Toto's Treehouse
# Targeted metric value: 3397
# Processing 2 records found for SONIC Drive-In
# Targeted metric value: 19373
# Processing 2 records found for Barbie™ Fashion Closet
# Targeted metric value: 68286
# Processing 2 records found for Shopular: Coupons, Weekly Ads & Shopping Deals
# Targeted metric value: 57920
# Processing 2 records found for VLC for Android
# Targeted metric value: 1032076
# Processing 2 records found for Video Downloader
# Targeted metric value: 59089
# Processing 2 records found for Accounting App - Zoho Books
# Targeted metric value: 3079
# Processing 2 records found for Hinge: Dating & Relationships
# Targeted metric value: 7779
# Processing 3 records found for Cut the Rope FULL FREE
# Targeted metric value: 2123793
# Processing 2 records found for Nurse Grid
# Targeted metric value: 1686
# Processing 2 records found for Home Workout - No Equipment
# Targeted metric value: 432160
# Processing 2 records found for Udacity - Lifelong Learning
# Targeted metric value: 22384
# Processing 3 records found for Google PDF Viewer
# Targeted metric value: 226456
# Processing 2 records found for Minecraft
# Targeted metric value: 2376564
# Processing 2 records found for Panera Bread
# Targeted metric value: 10225
# Processing 2 records found for HD Widgets
# Targeted metric value: 58617
# Processing 2 records found for To-Do Calendar Planner
# Targeted metric value: 30291
# Processing 2 records found for Workout Trainer: fitness coach
# Targeted metric value: 100406
# Processing 2 records found for All Mental disorders
# Targeted metric value: 453
# Processing 2 records found for Choices: Stories You Play
# Targeted metric value: 807338
# Processing 2 records found for Brilliant
# Targeted metric value: 41185
# Processing 2 records found for Casual Dating & Adult Singles - Joyride
# Targeted metric value: 61637
# Processing 3 records found for Free Blood Pressure
# Targeted metric value: 7
# Processing 2 records found for Android Messages
# Targeted metric value: 781810
# Processing 2 records found for Tiny Scanner Pro: PDF Doc Scan
# Targeted metric value: 10295
# Processing 2 records found for Cooking Fever
# Targeted metric value: 3198176
# Processing 2 records found for 95Live -SG#1 Live Streaming App
# Targeted metric value: 4954
# Processing 2 records found for Zomato - Restaurant Finder and Food Delivery App
# Targeted metric value: 511420
# Processing 3 records found for Super Jim Jump - pixel 3d
# Targeted metric value: 10460
# Processing 2 records found for Facebook
# Targeted metric value: 78158306
# Processing 3 records found for Hily: Dating, Chat, Match, Meet & Hook up
# Targeted metric value: 2560
# Processing 2 records found for Monster Truck Driver & Racing
# Targeted metric value: 765
# Processing 2 records found for Anger of stick 5 : zombie
# Targeted metric value: 549039
# Processing 2 records found for Brit + Co
# Targeted metric value: 987
# Processing 2 records found for Spanish English Translator
# Targeted metric value: 87919
# Processing 2 records found for Castle Clash: Heroes of the Empire US
# Targeted metric value: 4578890
# Processing 2 records found for Diabetes:M
# Targeted metric value: 15545
# Processing 2 records found for Mango Languages: Lovable Language Courses
# Targeted metric value: 4815
# Processing 2 records found for Tango - Live Video Broadcast
# Targeted metric value: 3806669
# Processing 2 records found for FOX
# Targeted metric value: 197774
# Processing 3 records found for join.me - Simple Meetings
# Targeted metric value: 6989
# Processing 2 records found for British Airways
# Targeted metric value: 25740
# Processing 2 records found for PicsArt Photo Studio: Collage Maker & Pic Editor
# Targeted metric value: 7594559
# Processing 5 records found for Granny
# Targeted metric value: 1138239
# Processing 2 records found for Lumosity: #1 Brain Games & Cognitive Training App
# Targeted metric value: 215301
# Processing 2 records found for Talkray - Free Calls & Texts
# Targeted metric value: 244863
# Processing 2 records found for My Little Pony Celebration
# Targeted metric value: 63192
# Processing 2 records found for Starbucks
# Targeted metric value: 455496
# Processing 2 records found for Zenefits
# Targeted metric value: 296
# Processing 2 records found for Simple - Better Banking
# Targeted metric value: 7731
# Processing 2 records found for Last Day on Earth: Survival
# Targeted metric value: 2311785
# Processing 2 records found for BZWBK24 mobile
# Targeted metric value: 64983
# Processing 2 records found for Apartments.com Rental Search
# Targeted metric value: 22584
# Processing 2 records found for Google Play Games
# Targeted metric value: 7168735
#
#
#
# App store original record count:7197, after duplicate removal: 7195
#
# Google Play original record count:10841, after duplicate removal: 9659

# %% [markdown]
# At this point, both data sets have unique records with well-formed rows.  We now attempt to detect non-English apps by their app names. The first step is to inspect characters that belong to outside the ASCII range, i.e. ordinal value beyond 127:

# %%
def get_non_ascii_characters(dataset_without_headers, app_name_index):
    non_ascii_list = []
    for app in dataset_without_headers:
        for character in app[app_name_index]:
            if ord(character) >= 128 and character not in non_ascii_list:
                non_ascii_list.append(character)
    return sorted(non_ascii_list)

apple_non_ascii_list = get_non_ascii_characters(apple_unique_cleaned_rows_apps_data, 1) # track_name at index 1
#print(apple_non_ascii_list)
google_non_ascii_list = get_non_ascii_characters(google_unique_cleaned_rows_apps_data, 0) # App at index 0
#print(google_non_ascii_list)

combined_non_ascii_list = [character for character in google_non_ascii_list]
for character in apple_non_ascii_list :
    if character not in combined_non_ascii_list:
        combined_non_ascii_list.append(character)

# The following print statement would result in a huge output that is mostly used for inspecting the non-ASCII characters
#print(sorted(combined_non_ascii_list))

# %% [markdown]
# At this point, we would make a discretionary whitelist of characters that should not be perceived as non-English, e.g. the Registered, Service Mark, Trademark symbols, as well as the emoticons that seem to be present in some of the app names.

# %%
def print_and_build_character_whitelist(character_list):
    result = []
    for character in character_list:
        if len(character) > 1:
            print('Bad character: ' +character)
        else:
            #print(character + ": "+str(ord(character)))
            result.append(ord(character))
    return result

# The following list is built after inspecting the print-out of the combined_non_ascii_list in the previous cell
character_whitelist = print_and_build_character_whitelist([
    '】','【','♥','、','»','〜','✨','⏰','Σ','✔','★','↔','Σ','★','―','►','🗓','～','·','▻','▫','∘','Ⅸ','●','Ⓞ',
    'С','！','－','：','∞','é','＆','•','—','’','–','®', '°', '²','⁴','℠', '™','🌏', '🌸', '🍀', '🎈', '🎨', '🏆', 
    '🏠', '🐈', '🐕', '🐬', '🐶', '👍', '💎', '💘', '💞', '💣', '📏', '📖', '🔔', '🔥', '🔫', '😂', '😄', '😍', 
    '😘', '😜', '🚀'])

# method for manual inspection of app names
def test_print(input, whitelist):
    index = 0
    for character in input:
        if ord(character) >= 128 and ord(character) not in whitelist:
            print(character + '('+str(index)+'): '+ str(ord(character)))
        index += 1

print('Size of whitelist: '+str(len(character_whitelist)))
# Out:
# Size of whitelist: 69

# %% [markdown]
# Finally, we filter the data sets to exclude apps with app names that contain characters with ordinal values outside of the ASCII and whitelist ranges.

# %%
def clean_non_english_apps(dataset_without_headers, app_name_index, whitelist):
    result = []
    non_english_list = []
    for app in dataset_without_headers: #iterate through apps in data-set
        is_containing_non_english_character = False
        for character in app[app_name_index]: #iterate through characters in app name
            if ord(character) >= 128 and ord(character) not in whitelist:
                is_containing_non_english_character = True
                break
        if is_containing_non_english_character == False:
            result.append(app)
        else:
            #print('Removing '+app[app_name_index])
            non_english_list.append(app)
    return result, non_english_list

apple_unique_cleaned_rows_english_apps_data, apple_non_english = clean_non_english_apps(apple_unique_cleaned_rows_apps_data, 1, character_whitelist) # track_name at index 1

google_unique_cleaned_rows_english_apps_data, google_non_english = clean_non_english_apps(google_unique_cleaned_rows_apps_data, 0, character_whitelist) # App at index 0

print('\nApp Store before non-English removal:' + str(len(apple_unique_cleaned_rows_apps_data)) + 
      ', after non-English removal: '+str(len(apple_unique_cleaned_rows_english_apps_data)) + 
     ', non-English list size: '+str(len(apple_non_english)))
print('Google Play before non-English removal:' + str(len(google_unique_cleaned_rows_apps_data)) + 
      ', after non-English removal: '+str(len(google_unique_cleaned_rows_english_apps_data)) + 
     ', non-English list size: '+str(len(google_non_english)))
# Out:
# App Store before non-English removal:7195, after non-English removal: 6109, non-English list size: 1086
# Google Play before non-English removal:9659, after non-English removal: 9480, non-English list size: 179

# %% [markdown]
# We have settled for 6109 records in the App Store data set, and 9480 records in the Google Play data set. These records have complete information, are unique and determined to be English-language apps.
#
# The last filter would be to pick only free apps, since our main goal is to analyse mobile apps that are free for users to download and use, while relying on the in-app advertisements as a means to generate revenue.

# %%
def get_free_apps(dataset_without_headers, price_index):
    result = []
    for app in dataset_without_headers:
        if float(app[price_index].replace('$','')) == 0.0:
            result.append(app)
    return result

apple_final_apps_data = get_free_apps(apple_unique_cleaned_rows_english_apps_data, 4) # price at index 4
google_final_apps_data = get_free_apps(google_unique_cleaned_rows_english_apps_data, 7) # price at index 7

print('\nApp Store before paid app removal: ' + str(len(apple_unique_cleaned_rows_english_apps_data)) +
     ', after paid app removal: '+str(len(apple_final_apps_data)))
print('\nGoogle Play before paid app removal: ' + str(len(google_unique_cleaned_rows_english_apps_data)) +
     ', after paid app removal: '+str(len(google_final_apps_data)))
# Out:
# App Store before paid app removal: 6109, after paid app removal: 3168
#
# Google Play before paid app removal: 9480, after paid app removal: 8742

# %% [markdown]
# At this point, we have completed to cleaning and filtering of data, to arrive at 3168 apps in the App Store and 8742 apps in Google Play that would be utilised for analysis.
#
#
#
# ## Most Common Genre In App Stores
#
# Firstly, we explore the most common genre of apps published in the respective stores. To do that, we would create helper functions that iterate through the data sets to count the number of occurences for each genre classification.

# %%
def freq_table(dataset_without_headers, target_index):
    result = {}
    for app in dataset_without_headers:
        if app[target_index] not in result.keys():
            result[app[target_index]] = 1
        else:
            result[app[target_index]] += 1
    return result

def display_table(data_dict):
    table_display = []
    for key in data_dict:
        key_val_as_tuple = (data_dict[key], key)
        table_display.append(key_val_as_tuple)

    table_sorted = sorted(table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

# %%
print('Top genres in App Store:\n')
apple_genre_dict = freq_table(apple_final_apps_data, apple_data_headers.index('prime_genre'))
display_table(apple_genre_dict)
# Out:
# Top genres in App Store:
#
# Games : 1851
# Entertainment : 252
# Photo & Video : 159
# Education : 117
# Social Networking : 104
# Shopping : 81
# Utilities : 76
# Sports : 68
# Music : 65
# Health & Fitness : 63
# Productivity : 54
# Lifestyle : 49
# News : 43
# Travel : 37
# Finance : 35
# Weather : 28
# Food & Drink : 26
# Reference : 17
# Business : 15
# Book : 12
# Navigation : 6
# Medical : 6
# Catalogs : 4

# %% [markdown]
# For the App Store, games are the most common apps, followed by apps that serve as tools (utilities, shopping, Photo & Video), community-building (Social Networking), learning (Education) and also for lifestyle activities (Entertainment, Sports, Music). Overall, apps aimed at leisurely persuits are the most common.
#
# Next, we look at the breakdown for the Google Play data set:

# %%
print('Top genres in Google Play:\n')
google_genre_dict = freq_table(google_final_apps_data, google_data_headers.index('Genres'))
display_table(google_genre_dict)

print('\nTop categories in Google Play:\n')
google_category_dict = freq_table(google_final_apps_data, google_data_headers.index('Category'))
display_table(google_category_dict)
# Out:
# Top genres in Google Play:
#
# Tools : 741
# Entertainment : 530
# Education : 467
# Business : 406
# Productivity : 344
# Lifestyle : 338
# Finance : 321
# Medical : 312
# Personalization : 293
# Sports : 285
# Communication : 283
# Action : 274
# Health & Fitness : 270
# Photography : 261
# News & Magazines : 241
# Social : 233
# Travel & Local : 204
# Shopping : 198
# Books & Reference : 187
# Simulation : 181
# Dating : 164
# Arcade : 161
# Video Players & Editors : 157
# Casual : 154
# Maps & Navigation : 118
# Food & Drink : 107
# Puzzle : 99
# Racing : 88
# Role Playing : 83
# Strategy : 81
# Libraries & Demo : 81
# Auto & Vehicles : 81
# Weather : 71
# House & Home : 71
# Events : 63
# Adventure : 59
# Beauty : 53
# Art & Design : 53
# Comics : 50
# Parenting : 44
# Card : 40
# Casino : 37
# Trivia : 35
# Educational;Education : 35
# Board : 34
# Educational : 32
# Education;Education : 30
# Word : 23
# Casual;Pretend Play : 21
# Music : 17
# Puzzle;Brain Games : 15
# Racing;Action & Adventure : 14
# Entertainment;Music & Video : 14
# Casual;Brain Games : 12
# Casual;Action & Adventure : 12
# Arcade;Action & Adventure : 11
# Action;Action & Adventure : 9
# Educational;Pretend Play : 8
# Simulation;Action & Adventure : 7
# Parenting;Education : 7
# Entertainment;Brain Games : 7
# Parenting;Music & Video : 6
# Educational;Brain Games : 6
# Casual;Creativity : 6
# Art & Design;Creativity : 6
# Education;Pretend Play : 5
# Board;Brain Games : 5
# Role Playing;Pretend Play : 4
# Education;Creativity : 4
# Role Playing;Action & Adventure : 3
# Puzzle;Action & Adventure : 3
# Entertainment;Creativity : 3
# Entertainment;Action & Adventure : 3
# Educational;Creativity : 3
# Educational;Action & Adventure : 3
# Education;Music & Video : 3
# Education;Brain Games : 3
# Education;Action & Adventure : 3
# Adventure;Action & Adventure : 3
# Video Players & Editors;Music & Video : 2
# Sports;Action & Adventure : 2
# Simulation;Pretend Play : 2
# Puzzle;Creativity : 2
# Music;Music & Video : 2
# Entertainment;Pretend Play : 2
# Casual;Education : 2
# Board;Action & Adventure : 2
# Video Players & Editors;Creativity : 1
# Trivia;Education : 1
# Travel & Local;Action & Adventure : 1
# Tools;Education : 1
# Strategy;Education : 1
# Strategy;Creativity : 1
# Strategy;Action & Adventure : 1
# Simulation;Education : 1
# Role Playing;Brain Games : 1
# Racing;Pretend Play : 1
# Puzzle;Education : 1
# Parenting;Brain Games : 1
# Music & Audio;Music & Video : 1
# Lifestyle;Pretend Play : 1
# Lifestyle;Education : 1
# Health & Fitness;Education : 1
# Health & Fitness;Action & Adventure : 1
# Entertainment;Education : 1
# Communication;Creativity : 1
# Comics;Creativity : 1
# Casual;Music & Video : 1
# Card;Action & Adventure : 1
# Books & Reference;Education : 1
# Art & Design;Pretend Play : 1
# Art & Design;Action & Adventure : 1
# Arcade;Pretend Play : 1
# Adventure;Education : 1
#
# Top categories in Google Play:
#
# FAMILY : 1654
# GAME : 853
# TOOLS : 742
# BUSINESS : 406
# PRODUCTIVITY : 344
# LIFESTYLE : 339
# FINANCE : 321
# MEDICAL : 312
# PERSONALIZATION : 293
# COMMUNICATION : 283
# SPORTS : 279
# HEALTH_AND_FITNESS : 270
# PHOTOGRAPHY : 261
# NEWS_AND_MAGAZINES : 241
# SOCIAL : 233
# TRAVEL_AND_LOCAL : 205
# SHOPPING : 198
# BOOKS_AND_REFERENCE : 187
# DATING : 164
# VIDEO_PLAYERS : 159
# MAPS_AND_NAVIGATION : 118
# FOOD_AND_DRINK : 107
# EDUCATION : 102
# ENTERTAINMENT : 85
# LIBRARIES_AND_DEMO : 81
# AUTO_AND_VEHICLES : 81
# WEATHER : 71
# HOUSE_AND_HOME : 71
# EVENTS : 63
# PARENTING : 58
# ART_AND_DESIGN : 57
# BEAUTY : 53
# COMICS : 51

# %% [markdown]
# Genres in Google Play seems to be very granular, so for a higher level perspective, we inspect the Categories data. Family seems to top the list, and upon a visit to the Google Play website, it is revealed that Family actually caters to games meant for kids.
#
# Hence, it can be concluded that games is the most common genre of apps in Google Play, followed by tools (tools, business, productivity, finance, medical, personalization, etc), lifestyle and communication.
#
# This analysis highlights similarities in both app stores, in which games are the most common apps being published, followed by tools and lifestyle.

# %% [markdown]
# ## Most Downloads In App Stores
#
# Another way of analysing the data sets is to look at the number of downloads clocked by the published apps. This could possibly give another perspective of app popularity among the user-base of both platforms. In other words, a type of app that draws in a larger user-base would have a greater chance of securing more ad-impressions within itself.
#
# For the iOS App store data set, we could use the rating_count_tot column to indirectly compute the number of app downloads. This is based on the assumption that a larger user-base would always lead to more ratings submitted.
#
# For the Google Play store data set, we could use the Installs column. However, that column is expressed in an approximate format, e.g. '1,000,000+', which cannot be cast as an integer immediately. Hence, the helper function would be augmented with a few more lines code to clean off the non-numeric characters to ensure the value can be parsed as a numeral.

# %%
def build_download_count(dataset_without_header, genre_index, count_index):
    genre_dict = {}
    result = {}
    non_number_set = (',','+') # to cope with the approximate exression in google data set
    for app in dataset_without_header:
        count_value = int(''.join([c for c in app[count_index] if c not in non_number_set]))
        if app[genre_index] not in genre_dict.keys():
            genre_dict[app[genre_index]] = [count_value]
        else:
            genre_dict[app[genre_index]].append(count_value)
    # iterate through the first dictionary to find average number of downloads per genre
    for genre,count_list in genre_dict.items():
        result[genre] = float(sum(count_list)) / len(count_list)
    return result

# %%
apple_download_dict = build_download_count(
    apple_final_apps_data, 
    apple_data_headers.index('prime_genre'),
    apple_data_headers.index('rating_count_tot'))

display_table(apple_download_dict)
# Out:
# Navigation : 86090.33333333333
# Reference : 79350.4705882353
# Social Networking : 72916.54807692308
# Music : 58205.03076923077
# Weather : 52279.892857142855
# Book : 46384.916666666664
# Food & Drink : 33333.92307692308
# Finance : 32367.02857142857
# Travel : 30524.297297297297
# Photo & Video : 28619.415094339623
# Shopping : 27898.802469135804
# Health & Fitness : 24037.634920634922
# Sports : 23101.926470588234
# Games : 23007.38141545111
# Productivity : 21799.14814814815
# News : 21248.023255813954
# Utilities : 19423.0
# Lifestyle : 15924.163265306122
# Entertainment : 14139.42857142857
# Business : 6839.6
# Education : 6010.940170940171
# Catalogs : 4004.0
# Medical : 612.0

# %% [markdown]
# Preliminary analysis seems to reveal that a navigation app would ensure the best chance of capturing a huge user-base on the iOS App Store, as it tops the table at ~86K average installations. Reference apps is a close 2nd at 79K, while Social Networking comes in 3rd at around 73K.

# %%
google_download_dict = build_download_count(
    google_final_apps_data, 
    google_data_headers.index('Category'),
    google_data_headers.index('Installs'))

display_table(google_download_dict)
# Out:
# COMMUNICATION : 38996132.830388695
# VIDEO_PLAYERS : 24727872.452830188
# SOCIAL : 23552836.060085837
# PHOTOGRAPHY : 17840110.40229885
# PRODUCTIVITY : 16833224.75
# GAME : 15749886.682297772
# TRAVEL_AND_LOCAL : 14120454.07804878
# ENTERTAINMENT : 11640705.88235294
# TOOLS : 10917152.700808626
# NEWS_AND_MAGAZINES : 9823830.746887967
# BOOKS_AND_REFERENCE : 8908439.893048128
# SHOPPING : 7072366.590909091
# PERSONALIZATION : 5219231.699658703
# WEATHER : 5074486.197183099
# HEALTH_AND_FITNESS : 4234992.192592593
# MAPS_AND_NAVIGATION : 4211061.694915255
# SPORTS : 3869044.505376344
# FAMILY : 3742179.6003627568
# ART_AND_DESIGN : 1986335.0877192982
# FOOD_AND_DRINK : 1978678.981308411
# EDUCATION : 1841666.6666666667
# BUSINESS : 1716495.2955665025
# LIFESTYLE : 1464520.1150442478
# FINANCE : 1383030.0062305296
# HOUSE_AND_HOME : 1367638.8873239437
# DATING : 859205.8353658536
# COMICS : 850218.6274509804
# LIBRARIES_AND_DEMO : 654244.5679012346
# AUTO_AND_VEHICLES : 654074.8271604938
# PARENTING : 542603.6206896552
# BEAUTY : 513151.88679245283
# EVENTS : 253542.22222222222
# MEDICAL : 120933.79487179487

# %% [markdown]
# Based on above results, it seems that Communication would have been a go-to genre with an average of >38M installations per app. However, upon closer inspection, it is revealed that there are several tech giants in this genre, such as WhatsApp (over 1B downloads) and LINE (over 500M downloads).  These exceedingly popular apps may be skewing the mean values, hence it would be folly to include them in our analysis.
#
# One possible solution would be to exclude these outliers. If we assume that installation-count for apps within a given genre fit a normal distribution, then according to this [Wiki article on normal distribution](https://en.wikipedia.org/wiki/Normal_distribution), about 68% of values drawn from a normal distribution are within 1 standard deviation away from the mean; about 95% of the values fall within 2 standard deviations; and about 99.7% are within 3 standard deviations.
#
# We then take the approach to remove the outlier counts by eliminating any apps that were above (Mean + 2*SD) and apps points below (Mean - 2*SD) before re-examining the statistics behind the trimmed list of apps.
#
# To test this alternative, we build another helper function to focus on the apps in COMMUNICATION genre for the Google Play data set:

# %%
def analyse_download_count(dataset_without_header, app_name_index, genre_index, count_index, target_genre):
    genre_dict = {}
    result = {}
    non_number_set = (',','+') # to cope with the approximate exression in google data set
    for app in dataset_without_header:
        count_value = int(''.join([c for c in app[count_index] if c not in non_number_set]))
        if app[genre_index] not in genre_dict.keys() and app[genre_index] == target_genre:
            genre_dict[app[genre_index]] = [[app[app_name_index], count_value]]
        else:
            if app[genre_index] == target_genre:
                genre_dict[app[genre_index]].append([app[app_name_index], count_value])
    # iterate through the first dictionary to find average number of downloads per genre
    for genre,count_list in genre_dict.items():
        print('Processing ['+genre+'] genre:')
        avg = float(sum([item[1] for item in count_list])) / len(count_list)
        pop_standard_dev = statistics.pstdev([item[1] for item in count_list])
        print('Mean: ' + str(avg) + ', Population standard deviation:' + str(pop_standard_dev))
        final_list = []
        exclusion_list = []
        for item in count_list:
            if abs(item[1] - avg) > (2 * pop_standard_dev):
                #print(item[0] +' ('+str(item[1])+') excluded as >2 standard deviations away from mean')
                exclusion_list.append(item)
            else:
                #print(item[0] +' ('+str(item[1])+') included as within 2 standard deviations away from mean')
                final_list.append(item)
        print('Size of original app list:'+str(len(count_list))+', Size of trimmed list:'+str(len(final_list))+'\n')
        result[genre] = sum([item[1] for item in final_list]) / len(final_list)
        
    return result, final_list, exclusion_list

# %%
google_download_dict_COMMUNICATION, good_list, outliers = analyse_download_count(google_final_apps_data,
                                                         google_data_headers.index('App'),
                                                         google_data_headers.index('Category'),
                                                         google_data_headers.index('Installs'),
                                                         'COMMUNICATION')

display_table(google_download_dict_COMMUNICATION)
print('\nOutliers (>2 std devs) in COMMUNICATION genre:')
for app in outliers:
    print(app[0]+', '+str(app[1]))
# Out:
# Processing [COMMUNICATION] genre:
# Mean: 38996132.830388695, Population standard deviation:157296436.36876735
# Size of original app list:283, Size of trimmed list:272
#
# COMMUNICATION : 9323182.31985294
#
# Outliers (>2 std devs) in COMMUNICATION genre:
# Viber Messenger, 500000000
# Messenger – Text and Video Chat for Free, 1000000000
# imo free video calls and chat, 500000000
# Hangouts, 1000000000
# Google Chrome: Fast & Secure, 1000000000
# Gmail, 1000000000
# LINE: Free Calls & Messages, 500000000
# Google Duo - High Quality Video Calls, 500000000
# WhatsApp Messenger, 1000000000
# Skype - free IM & video calls, 1000000000
# UC Browser - Fast Download Private & Secure, 500000000

# %% [markdown]
# As shown above, just by removing 11 outliers from the original list of 283 apps in the COMMUNICATION genre, the mean value of downloads have been revised from 38.9M to just 9.3M. It can be said that the presence of a few outliers can distort the outlook of certain genres.
#
# This time, we process all genres using this trimmed-mean mechanism:

# %%
def build_2sd_download_count(dataset_without_header, app_name_index, genre_index, count_index):
    genre_dict = {}
    result = {}
    non_number_set = (',','+') # to cope with the approximate exression in google data set
    for app in dataset_without_header:
        count_value = int(''.join([c for c in app[count_index] if c not in non_number_set]))
        if app[genre_index] not in genre_dict.keys():
            genre_dict[app[genre_index]] = [[app[app_name_index], count_value]]
        else:
            genre_dict[app[genre_index]].append([app[app_name_index], count_value])
    # iterate through the first dictionary to find average number of downloads per genre
    inclusion_dict = {}
    exclusion_dict = {}
    for genre,count_list in genre_dict.items():
        print('Processing ['+genre+'] genre:')
        avg = float(sum([item[1] for item in count_list])) / len(count_list)
        pop_standard_dev = statistics.pstdev([item[1] for item in count_list])
        
        final_list = []
        exclusion_list = []
        for item in count_list:
            if abs(item[1] - avg) > (2 * pop_standard_dev):
                #print(item[0] +' ('+str(item[1])+') excluded as >2 standard deviations away from mean')
                exclusion_list.append(item)
            else:
                #print(item[0] +' ('+str(item[1])+') included as within 2 standard deviations away from mean')
                final_list.append(item)
        print('Size of original app list:'+str(len(count_list))+', Size of trimmed list:'+str(len(final_list)))
        result[genre] = sum([item[1] for item in final_list]) / len(final_list)
        print('Original Avg: ' + str(avg) + ', Pstdev:' + str(pop_standard_dev)+', Trimmed Avg:'+str(result[genre]))
        inclusion_dict[genre] = final_list
        exclusion_dict[genre] = exclusion_list
        
    return result, inclusion_dict, exclusion_dict

# %%
google_download_2sd_dict, inclusion_dict, exclusion_dic = build_2sd_download_count(google_final_apps_data,
                                                         google_data_headers.index('App'),
                                                         google_data_headers.index('Category'),
                                                         google_data_headers.index('Installs'))
print('\n\n')
display_table(google_download_2sd_dict)
# Out:
# Processing [VIDEO_PLAYERS] genre:
# Size of original app list:159, Size of trimmed list:156
# Original Avg: 24727872.452830188, Pstdev:118708611.49289133, Trimmed Avg:9177767.435897436
# Processing [LIFESTYLE] genre:
# Size of original app list:339, Size of trimmed list:337
# Original Avg: 1464520.1150442478, Pstdev:6499340.809699266, Trimmed Avg:1028107.7715133531
# Processing [ENTERTAINMENT] genre:
# Size of original app list:85, Size of trimmed list:80
# Original Avg: 11640705.88235294, Pstdev:24444494.088985275, Trimmed Avg:6118250.0
# Processing [COMMUNICATION] genre:
# Size of original app list:283, Size of trimmed list:272
# Original Avg: 38996132.830388695, Pstdev:157296436.36876735, Trimmed Avg:9323182.31985294
# Processing [PHOTOGRAPHY] genre:
# Size of original app list:261, Size of trimmed list:260
# Original Avg: 17840110.40229885, Pstdev:66618742.73719847, Trimmed Avg:14062572.365384616
# Processing [BOOKS_AND_REFERENCE] genre:
# Size of original app list:187, Size of trimmed list:186
# Original Avg: 8908439.893048128, Pstdev:74119027.4778833, Trimmed Avg:3579990.64516129
# Processing [FAMILY] genre:
# Size of original app list:1654, Size of trimmed list:1640
# Original Avg: 3742179.6003627568, Pstdev:26957745.522430357, Trimmed Avg:2371686.011585366
# Processing [ART_AND_DESIGN] genre:
# Size of original app list:57, Size of trimmed list:56
# Original Avg: 1986335.0877192982, Pstdev:6952597.719002418, Trimmed Avg:1128948.2142857143
# Processing [MEDICAL] genre:
# Size of original app list:312, Size of trimmed list:310
# Original Avg: 120933.79487179487, Pstdev:456099.3258040896, Trimmed Avg:89455.94838709677
# Processing [TRAVEL_AND_LOCAL] genre:
# Size of original app list:205, Size of trimmed list:203
# Original Avg: 14120454.07804878, Pstdev:98825197.85149826, Trimmed Avg:4407355.1034482755
# Processing [WEATHER] genre:
# Size of original app list:71, Size of trimmed list:67
# Original Avg: 5074486.197183099, Pstdev:11487497.003942456, Trimmed Avg:2392365.970149254
# Processing [DATING] genre:
# Size of original app list:164, Size of trimmed list:156
# Original Avg: 859205.8353658536, Pstdev:2280196.062493181, Trimmed Avg:390447.16025641025
# Processing [PRODUCTIVITY] genre:
# Size of original app list:344, Size of trimmed list:339
# Original Avg: 16833224.75, Pstdev:78212379.22719242, Trimmed Avg:8231944.879056048
# Processing [NEWS_AND_MAGAZINES] genre:
# Size of original app list:241, Size of trimmed list:238
# Original Avg: 9823830.746887967, Pstdev:78407765.99107814, Trimmed Avg:1544299.2016806724
# Processing [FINANCE] genre:
# Size of original app list:321, Size of trimmed list:319
# Original Avg: 1383030.0062305296, Pstdev:6526218.348995629, Trimmed Avg:921481.605015674
# Processing [AUTO_AND_VEHICLES] genre:
# Size of original app list:81, Size of trimmed list:76
# Original Avg: 654074.8271604938, Pstdev:1773702.7412475105, Trimmed Avg:236579.75
# Processing [SOCIAL] genre:
# Size of original app list:233, Size of trimmed list:228
# Original Avg: 23552836.060085837, Pstdev:121978648.42445417, Trimmed Avg:6525485.97368421
# Processing [BUSINESS] genre:
# Size of original app list:406, Size of trimmed list:399
# Original Avg: 1716495.2955665025, Pstdev:9017646.817774132, Trimmed Avg:618789.6992481203
# Processing [BEAUTY] genre:
# Size of original app list:53, Size of trimmed list:51
# Original Avg: 513151.88679245283, Pstdev:1508702.171115464, Trimmed Avg:239157.8431372549
# Processing [SPORTS] genre:
# Size of original app list:279, Size of trimmed list:270
# Original Avg: 3869044.505376344, Pstdev:11577290.732618058, Trimmed Avg:1960975.6185185185
# Processing [LIBRARIES_AND_DEMO] genre:
# Size of original app list:81, Size of trimmed list:76
# Original Avg: 654244.5679012346, Pstdev:2003049.2833542067, Trimmed Avg:170971.18421052632
# Processing [GAME] genre:
# Size of original app list:853, Size of trimmed list:848
# Original Avg: 15749886.682297772, Pstdev:53906533.67677632, Trimmed Avg:12305015.731132075
# Processing [PARENTING] genre:
# Size of original app list:58, Size of trimmed list:56
# Original Avg: 542603.6206896552, Pstdev:1449407.5307264503, Trimmed Avg:294125.1785714286
# Processing [EDUCATION] genre:
# Size of original app list:102, Size of trimmed list:94
# Original Avg: 1841666.6666666667, Pstdev:2795318.9454042534, Trimmed Avg:1147340.425531915
# Processing [COMICS] genre:
# Size of original app list:51, Size of trimmed list:46
# Original Avg: 850218.6274509804, Pstdev:1848380.550192381, Trimmed Avg:290459.7826086957
# Processing [HEALTH_AND_FITNESS] genre:
# Size of original app list:270, Size of trimmed list:268
# Original Avg: 4234992.192592593, Pstdev:31113341.561821718, Trimmed Avg:2027790.6417910447
# Processing [PERSONALIZATION] genre:
# Size of original app list:293, Size of trimmed list:280
# Original Avg: 5219231.699658703, Pstdev:17358921.590682156, Trimmed Avg:1711553.1714285715
# Processing [EVENTS] genre:
# Size of original app list:63, Size of trimmed list:61
# Original Avg: 253542.22222222222, Pstdev:893811.5291577858, Trimmed Avg:97920.65573770492
# Processing [TOOLS] genre:
# Size of original app list:742, Size of trimmed list:736
# Original Avg: 10917152.700808626, Pstdev:57561026.28066103, Trimmed Avg:6250716.445652174
# Processing [MAPS_AND_NAVIGATION] genre:
# Size of original app list:118, Size of trimmed list:114
# Original Avg: 4211061.694915255, Pstdev:14345129.369986217, Trimmed Avg:1727239.298245614
# Processing [HOUSE_AND_HOME] genre:
# Size of original app list:71, Size of trimmed list:66
# Original Avg: 1367638.8873239437, Pstdev:2628639.6285671615, Trimmed Avg:713672.1363636364
# Processing [SHOPPING] genre:
# Size of original app list:198, Size of trimmed list:186
# Original Avg: 7072366.590909091, Pstdev:17725470.16579515, Trimmed Avg:2958755.8333333335
# Processing [FOOD_AND_DRINK] genre:
# Size of original app list:107, Size of trimmed list:94
# Original Avg: 1978678.981308411, Pstdev:3291201.6424221196, Trimmed Avg:869347.3510638297
#
#
#
# PHOTOGRAPHY : 14062572.365384616
# GAME : 12305015.731132075
# COMMUNICATION : 9323182.31985294
# VIDEO_PLAYERS : 9177767.435897436
# PRODUCTIVITY : 8231944.879056048
# SOCIAL : 6525485.97368421
# TOOLS : 6250716.445652174
# ENTERTAINMENT : 6118250.0
# TRAVEL_AND_LOCAL : 4407355.1034482755
# BOOKS_AND_REFERENCE : 3579990.64516129
# SHOPPING : 2958755.8333333335
# WEATHER : 2392365.970149254
# FAMILY : 2371686.011585366
# HEALTH_AND_FITNESS : 2027790.6417910447
# SPORTS : 1960975.6185185185
# MAPS_AND_NAVIGATION : 1727239.298245614
# PERSONALIZATION : 1711553.1714285715
# NEWS_AND_MAGAZINES : 1544299.2016806724
# EDUCATION : 1147340.425531915
# ART_AND_DESIGN : 1128948.2142857143
# LIFESTYLE : 1028107.7715133531
# FINANCE : 921481.605015674
# FOOD_AND_DRINK : 869347.3510638297
# HOUSE_AND_HOME : 713672.1363636364
# BUSINESS : 618789.6992481203
# DATING : 390447.16025641025
# PARENTING : 294125.1785714286
# COMICS : 290459.7826086957
# BEAUTY : 239157.8431372549
# AUTO_AND_VEHICLES : 236579.75
# LIBRARIES_AND_DEMO : 170971.18421052632
# EVENTS : 97920.65573770492
# MEDICAL : 89455.94838709677

# %% [markdown]
# Based on the revised set of results, PHOTOGRAPHY tops the list with 14M average downloads, followed by GAME at over 12M, then COMMUNICATION at over 9M. It should be prudent to suggest building a decent photography app which would appeal to the camera-eager generation!
#
# While games come in as a close 2nd, a game app would face nearly 3 times more competition (852 game apps in original data set), compared to photography apps (261 photo apps in original data set). In other words, it might be 3 time harder to differentiate one's game app in the current Google Play market, compared to a photography app.

# %%
apple_download_2sd_dict, apple_inclusion_dict, apple_exclusion_dic = build_2sd_download_count(apple_final_apps_data,
                                                         apple_data_headers.index('track_name'),
                                                         apple_data_headers.index('prime_genre'),
                                                         apple_data_headers.index('rating_count_tot'))
print('\n\n')
display_table(apple_download_2sd_dict)
# Out:
# Processing [Games] genre:
# Size of original app list:1851, Size of trimmed list:1807
# Original Avg: 23007.38141545111, Pstdev:95366.8249476728, Trimmed Avg:11838.421693414499
# Processing [Travel] genre:
# Size of original app list:37, Size of trimmed list:35
# Original Avg: 30524.297297297297, Pstdev:81778.48709309765, Trimmed Avg:13123.685714285713
# Processing [Photo & Video] genre:
# Size of original app list:159, Size of trimmed list:158
# Original Avg: 28619.415094339623, Pstdev:174213.9422495501, Trimmed Avg:15119.803797468354
# Processing [Reference] genre:
# Size of original app list:17, Size of trimmed list:16
# Original Avg: 79350.4705882353, Pstdev:231344.8278406113, Trimmed Avg:22689.875
# Processing [Medical] genre:
# Size of original app list:6, Size of trimmed list:6
# Original Avg: 612.0, Pstdev:606.3384643359955, Trimmed Avg:612.0
# Processing [Productivity] genre:
# Size of original app list:54, Size of trimmed list:50
# Original Avg: 21799.14814814815, Pstdev:35502.81431171515, Trimmed Avg:12864.06
# Processing [Lifestyle] genre:
# Size of original app list:49, Size of trimmed list:47
# Original Avg: 15924.163265306122, Pstdev:53432.056491893854, Trimmed Avg:6261.170212765957
# Processing [Utilities] genre:
# Size of original app list:76, Size of trimmed list:75
# Original Avg: 19423.0, Pstdev:60153.07413722007, Trimmed Avg:13289.44
# Processing [Finance] genre:
# Size of original app list:35, Size of trimmed list:33
# Original Avg: 32367.02857142857, Pstdev:59045.34579044711, Trimmed Avg:20201.090909090908
# Processing [Shopping] genre:
# Size of original app list:81, Size of trimmed list:79
# Original Avg: 27898.802469135804, Pstdev:60517.14246932302, Trimmed Avg:19997.25316455696
# Processing [Entertainment] genre:
# Size of original app list:252, Size of trimmed list:241
# Original Avg: 14139.42857142857, Pstdev:39036.66379104872, Trimmed Avg:7207.746887966805
# Processing [Weather] genre:
# Size of original app list:28, Size of trimmed list:27
# Original Avg: 52279.892857142855, Pstdev:105319.92573390689, Trimmed Avg:35859.666666666664
# Processing [Catalogs] genre:
# Size of original app list:4, Size of trimmed list:4
# Original Avg: 4004.0, Pstdev:5438.3090202745925, Trimmed Avg:4004.0
# Processing [Education] genre:
# Size of original app list:117, Size of trimmed list:113
# Original Avg: 6010.940170940171, Pstdev:18908.09735387009, Trimmed Avg:3005.221238938053
# Processing [Business] genre:
# Size of original app list:15, Size of trimmed list:14
# Original Avg: 6839.6, Pstdev:10179.24340868875, Trimmed Avg:4565.214285714285
# Processing [Sports] genre:
# Size of original app list:68, Size of trimmed list:63
# Original Avg: 23101.926470588234, Pstdev:50885.22424111073, Trimmed Avg:10213.0
# Processing [Navigation] genre:
# Size of original app list:6, Size of trimmed list:5
# Original Avg: 86090.33333333333, Pstdev:128297.74908088693, Trimmed Avg:34299.2
# Processing [News] genre:
# Size of original app list:43, Size of trimmed list:42
# Original Avg: 21248.023255813954, Pstdev:59005.731320557985, Trimmed Avg:13323.97619047619
# Processing [Food & Drink] genre:
# Size of original app list:26, Size of trimmed list:24
# Original Avg: 33333.92307692308, Pstdev:77580.93872105594, Trimmed Avg:12675.083333333334
# Processing [Social Networking] genre:
# Size of original app list:104, Size of trimmed list:102
# Original Avg: 72916.54807692308, Pstdev:311805.55488856044, Trimmed Avg:34774.71568627451
# Processing [Book] genre:
# Size of original app list:12, Size of trimmed list:11
# Original Avg: 46384.916666666664, Pstdev:72137.0819475651, Trimmed Avg:27685.727272727272
# Processing [Music] genre:
# Size of original app list:65, Size of trimmed list:63
# Original Avg: 58205.03076923077, Pstdev:182242.17423332986, Trimmed Avg:28220.396825396827
# Processing [Health & Fitness] genre:
# Size of original app list:63, Size of trimmed list:61
# Original Avg: 24037.634920634922, Pstdev:80209.11170191062, Trimmed Avg:10374.262295081968
#
#
#
# Weather : 35859.666666666664
# Social Networking : 34774.71568627451
# Navigation : 34299.2
# Music : 28220.396825396827
# Book : 27685.727272727272
# Reference : 22689.875
# Finance : 20201.090909090908
# Shopping : 19997.25316455696
# Photo & Video : 15119.803797468354
# News : 13323.97619047619
# Utilities : 13289.44
# Travel : 13123.685714285713
# Productivity : 12864.06
# Food & Drink : 12675.083333333334
# Games : 11838.421693414499
# Health & Fitness : 10374.262295081968
# Sports : 10213.0
# Entertainment : 7207.746887966805
# Lifestyle : 6261.170212765957
# Business : 4565.214285714285
# Catalogs : 4004.0
# Education : 3005.221238938053
# Medical : 612.0

# %% [markdown]
# Considering the iOS App Store alone, a weather app would seem like a good choice as it tops the list of average installations at close to 36K.  Again, we would want to avoid the Social Network space that is already dominated by earlier mentioned tech giants. Navigation could be a good choice too, with users constantly seeking a useful map app that could help them navigate around urban areas.

# %% [markdown]
# After applying the same trimmed-mean analysis to the iOS App Store, we now have 2 top-10 tables to consider:
#
# | iOS App | Count |
# | ------- | ----- |
# | Weather | 35859.666666666664 |
# | Social Networking | 34774.71568627451 |
# | Navigation | 34299.2 |
# | Music | 28220.396825396827 |
# | Book | 27685.727272727272 |
# | Reference | 22689.875 |
# | Finance | 20201.090909090908 |
# | Shopping | 19997.25316455696 |
# | Photo & Video | 15119.803797468354 |
# | News | 13323.97619047619 |
#
# | Google Play App | Count |
# | --------------- | ----- |
# | PHOTOGRAPHY | 14062572.365384616 |
# | GAME | 12305015.731132075 |
# | COMMUNICATION | 9323182.31985294 |
# | VIDEO_PLAYERS | 9177767.435897436 |
# | PRODUCTIVITY | 8231944.879056048 |
# | SOCIAL | 6525485.97368421 |
# | TOOLS | 6250716.445652174 |
# | ENTERTAINMENT | 6118250.0 |
# | TRAVEL_AND_LOCAL | 4407355.1034482755 |
# | BOOKS_AND_REFERENCE | 3579990.64516129 |
#
#
#
# ## Final Analysis & Conclusion
# If we were to consider only app types that appear in both tables, it would be:
# - Social Network
# - Photography
# - Book/Reference
#
# As discussed earlier, it would be prudent to avoid avoid genres that have several tech giants reigning the market space with their immense popularity. As such, a Social Network app would hardly gain traction in the face of household names like Facebook and Google. Photography seems like a good choice, though you may be competing with the likes of Instagram and Snapchat.
#
# Book/Reference seems a surprising entry for both platforms. With a sizable user-base, few exceedingly successful outliers to compete with, and likely unsaturated market space (earlier mentioned that games, tools and lifestyle genre are the most populated), it might be good to consider some sort of a e-reader app that would allow users to read books or look up references on just about any subject while on the go.
